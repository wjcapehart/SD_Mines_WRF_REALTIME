# %% [markdown]
# # Plot Time Series w/ Observations

# %% [markdown]
# ## Libraries

# %%
####################################################
####################################################
####################################################
#
# Libraries
#

import numpy             as np
import datetime          as datetime
import os                as os
import platform          as platform
import xarray            as xr
import pandas            as pd
import glob              as glob
import siphon.catalog    as siphcat  
import siphon.ncss       as siphncss
import seaborn           as sns
import matplotlib.pyplot as plt
import pint_xarray       as px
import matplotlib.dates  as mdates
import timezonefinder    as tzf
import pytz              as pytz
import haversine         as hs
import socket            as socket
import metpy.calc        as mpcalc
import metpy.units       as mpunits

import metpy.io          as mpio
from metpy.cbook import get_test_data
from siphon.catalog import TDSCatalog

import matplotlib.font_manager as fm
import matplotlib as mpl
import airportsdata as airpt

from requests import HTTPError

import urllib.request
import shutil


from metpy.units import units

import requests


os.chdir("/Users/wjc/GitHub/SD_Mines_WRF_REALTIME/test_area/")
os.getcwd()
#
####################################################
####################################################
####################################################
# Out:
# '/Users/wjc/GitHub/SD_Mines_WRF_REALTIME/test_area'

# %% [markdown]
# ## File Organization

# %%
####################################################
####################################################
####################################################
#
# File Organization
#

beta_on     = 0
max_domains = 3

if (socket.gethostname() == "kyrill"):
    WRF_OVERALL_DIR = "/projects/SD_Mines_WRF_REALTIME/"
else:
    if (platform.system() == "Darwin"):
         WRF_OVERALL_DIR = "/Users/wjc/GitHub/SD_Mines_WRF_REALTIME/"
    else:
         WRF_OVERALL_DIR = "/home/wjc/GitHub/SD_Mines_WRF_REALTIME/"



print( "Current Working Directory is now " + os.getcwd() )
    
WPS_WORK    = WRF_OVERALL_DIR + "./WPS_PrepArea/"
WPS_EXE     = WRF_OVERALL_DIR + "./WRF4/WPS/"
WRF_EXE     = WRF_OVERALL_DIR + "./WRF4/WRF/test/em_real/"
WRF_ARCHIVE = WRF_OVERALL_DIR + "./ARCHIVE/"
WRF_IMAGES  = WRF_OVERALL_DIR + "./WEB_IMAGES/"



station_list_file = WRF_OVERALL_DIR + "namelist_files_and_local_scripts/time_series_station_files_"+str(max_domains)+"_dom_all.xlsx"


#
####################################################
####################################################
####################################################
# Out:
# Current Working Directory is now /Users/wjc/GitHub/SD_Mines_WRF_REALTIME/test_area

# %% [markdown]
# ## Time Control

# %%
####################################################
####################################################
####################################################
#
# Model Start Date
#

with open(WRF_ARCHIVE  + "./current_complete_run/current_run.txt") as f:
    model_start_date_YYYY_MM_DD_HH = f.readlines()

model_start_date_YYYY_MM_DD_HH     = model_start_date_YYYY_MM_DD_HH[0][0:13]

model_start_date_YYYY_MM_DD_HH0000 = model_start_date_YYYY_MM_DD_HH + ":00:00"
print(model_start_date_YYYY_MM_DD_HH0000)
    
model_start_datetime = datetime.datetime.strptime(model_start_date_YYYY_MM_DD_HH0000, '%Y-%m-%d_%H:%M:%S')
print("Model Simulation Date ", model_start_datetime)
    
model_end_datetime   = model_start_datetime + datetime.timedelta(hours=36)
current_datetime     = datetime.datetime.utcnow()
siphon_end_datetime  = min(current_datetime,model_end_datetime)

print("         Model Start Datetime is ", model_start_datetime)
print("           Model End Datetime is ",   model_end_datetime)
print("             Current Datetime is ",     current_datetime)
print("          Siphon End Datetime is ",  siphon_end_datetime)

siphon_time_series       = pd.date_range(model_start_datetime, siphon_end_datetime,freq='H')
siphon_pulls_YYYYMMDD_HH = siphon_time_series.strftime("%Y%m%d_%H00")

print(siphon_pulls_YYYYMMDD_HH)

#
####################################################
####################################################
####################################################
# Out:
# 2021-10-26_06:00:00
# Model Simulation Date  2021-10-26 06:00:00
#          Model Start Datetime is  2021-10-26 06:00:00
#            Model End Datetime is  2021-10-27 18:00:00
#              Current Datetime is  2021-10-26 19:28:37.344550
#           Siphon End Datetime is  2021-10-26 19:28:37.344550
# Index(['20211026_0600', '20211026_0700', '20211026_0800', '20211026_0900',
#        '20211026_1000', '20211026_1100', '20211026_1200', '20211026_1300',
#        '20211026_1400', '20211026_1500', '20211026_1600', '20211026_1700',
#        '20211026_1800', '20211026_1900'],
#       dtype='object')

# %% [markdown]
# ## Read tslist excel file and Airport Database

# %%
####################################################
####################################################
####################################################
#
# Read TSLIST Excel File
#

print("read file from "+station_list_file)

available_time_series_list = pd.read_excel(station_list_file,
                                           index_col=0)

print(available_time_series_list)

#
# Get Data 
#

airport_database = airpt.load('ICAO')

#
####################################################
####################################################
####################################################
# Out:
# read file from /Users/wjc/GitHub/SD_Mines_WRF_REALTIME/namelist_files_and_local_scripts/time_series_station_files_3_dom_all.xlsx
#           Station ID  Domain            Station Name  Latitude  Longitude  \
# Row Label
# 26              KUNR       3      Rapid City NWS, SD   44.0727   -103.211
# 21              KRCA       3       Ellsworth AFB, SD   44.1330   -103.100
# 20              KRAP       3     Rapid City Arpt, SD   44.0430   -103.054
# 25              KUDX       3  Rapid City, NEXRAD, SD   44.1330   -102.833
# 7               KCUT       3         Custer Arpt, SD   43.7330   -103.611
# 23              KSPF       3     Clyde Ice Field, SD   44.4830   -103.783
# 10              KEFC       3  Belle Fourche Muni, SD   44.7340   -103.862
# 28              KW43       3         Hulett Arpt, WY   44.6629   -104.568
# 18              KPHP       2         Philip Arpt, SD   44.0510   -101.601
# 15              KIEN       2     Pine Ridge Arpt, SD   43.0210   -102.518
# 6               KCDR       2     Chadron Airport, NE   42.8370   -103.098
# 2               K4MC       2           Moorcroft, WY   44.2670   -104.950
# 8               KD07       2       Faith Airport, SD   45.0320   -102.019
# 12              KGRN       2         Gordon Muni, NE   42.8060   -102.175
# 0               K2WX       2             Buffalo, SD   45.6040   -103.546
# 11              KGCC       2       Gillette Arpt, WY   44.3390   -105.542
# 14              KHEI       2      Hettinger Arpt, ND   46.0170   -102.650
# 29              KY22       2              Lemmon, SD   45.9330   -102.167
# 16              KLEM       2         Lemmon Arpt, SD   45.9190   -102.106
# 9               KDGW       2    Converse Co Arpt, WY   42.7960   -105.380
# 3               KAIA       1       Alliance Arpt, NE   42.0500   -102.800
# 1               K4DG       2             Douglas, WY   42.7500   -105.383
# 22              KSIB       1         Sibley Peak, WY   42.4330   -105.033
# 19              KPIR       2         Pierre Arpt, SD   44.3810   -100.286
# 5               KBPP       2         Bowman Arpt, ND   46.1870   -103.428
# 24              KTOR       1     Torrington Arpt, WY   42.0610   -104.158
# 17              KMIS       2             Mission, SD   43.0330   -100.617
# 4               KBFF       1    Scottsbluff Arpt, NE   41.8710   -103.593
# 27              KVTN       2   Miller Field Arpt, NE   42.8780   -100.550
# 30              MUNS       1       Munich School, ND   48.6667    -98.835
#
#            Distane from SDMines
# Row Label
# 26                     0.440247
# 21                    10.688775
# 20                    12.624087
# 25                    30.484424
# 7                     49.927564
# 23                    64.629983
# 10                    89.994938
# 28                   126.519155
# 18                   128.259607
# 15                   129.569530
# 6                    137.845928
# 2                    140.743165
# 8                    142.080009
# 12                   163.745344
# 0                    172.206435
# 11                   188.512672
# 14                   220.398591
# 29                   222.238035
# 16                   222.613287
# 9                    225.856417
# 3                    227.482904
# 1                    229.345787
# 22                   234.931317
# 19                   235.131061
# 5                    235.577856
# 24                   236.837323
# 17                   238.584887
# 4                    247.000181
# 27                   252.207141
# 30                   610.696746

# %%
####################################################
####################################################
####################################################
#
# Pull METARS from UNIDATA NOAAPORT Experimental Site
#

# https://thredds-test.unidata.ucar.edu/thredds/fileServer/noaaport/text/metar/metar_20210924_0000.txt

cat = TDSCatalog('https://thredds-test.unidata.ucar.edu/thredds/catalog/noaaport/text/metar/catalog.xml')



first = True
for datehour in siphon_pulls_YYYYMMDD_HH:
    

    
    metar_url  = "https://thredds-test.unidata.ucar.edu/thredds/fileServer/noaaport/text/metar/metar_"+datehour+".txt"
    metar_file = "deleteme.txt"
    
    print(metar_url)

    with urllib.request.urlopen(metar_url) as response, open(metar_file, 'wb') as out_file:
        shutil.copyfileobj(response, out_file)
        
    try:
        indata = mpio.metar.parse_metar_file(metar_file)
        if first:
            first = False
            metar_dataframe = indata
        else:
            metar_dataframe = metar_dataframe.append(indata)
            metar_dataframe = metar_dataframe.drop_duplicates()
    except ValueError:
        print("BALLS! Parse Error")
        error_404 = True
        pass
    os.system("rm -frv ./deleteme.txt")


        
        

display(metar_dataframe)


station_locs = metar_dataframe[["station_id","latitude","longitude"]].drop_duplicates()





#
####################################################
####################################################
####################################################
# Out:
# https://thredds-test.unidata.ucar.edu/thredds/fileServer/noaaport/text/metar/metar_20211026_0600.txt
# https://thredds-test.unidata.ucar.edu/thredds/fileServer/noaaport/text/metar/metar_20211026_0700.txt
# https://thredds-test.unidata.ucar.edu/thredds/fileServer/noaaport/text/metar/metar_20211026_0800.txt
# https://thredds-test.unidata.ucar.edu/thredds/fileServer/noaaport/text/metar/metar_20211026_0900.txt
# https://thredds-test.unidata.ucar.edu/thredds/fileServer/noaaport/text/metar/metar_20211026_1000.txt
# https://thredds-test.unidata.ucar.edu/thredds/fileServer/noaaport/text/metar/metar_20211026_1100.txt
# https://thredds-test.unidata.ucar.edu/thredds/fileServer/noaaport/text/metar/metar_20211026_1200.txt
# https://thredds-test.unidata.ucar.edu/thredds/fileServer/noaaport/text/metar/metar_20211026_1300.txt
# https://thredds-test.unidata.ucar.edu/thredds/fileServer/noaaport/text/metar/metar_20211026_1400.txt
# https://thredds-test.unidata.ucar.edu/thredds/fileServer/noaaport/text/metar/metar_20211026_1500.txt
# https://thredds-test.unidata.ucar.edu/thredds/fileServer/noaaport/text/metar/metar_20211026_1600.txt
# https://thredds-test.unidata.ucar.edu/thredds/fileServer/noaaport/text/metar/metar_20211026_1700.txt
# https://thredds-test.unidata.ucar.edu/thredds/fileServer/noaaport/text/metar/metar_20211026_1800.txt
# https://thredds-test.unidata.ucar.edu/thredds/fileServer/noaaport/text/metar/metar_20211026_1900.txt
#            station_id   latitude  longitude  elevation           date_time  \
# station_id
# KMJD             KMJD  30.483333     -89.65       17.0 2021-10-26 05:55:00
# PAKU             PAKU  70.310000    -149.58        2.0 2021-10-26 05:45:00
# KRYY             KRYY  34.020000     -84.60      317.0 2021-10-26 05:50:00
# KQEI             KQEI  37.970000     128.08      195.0 2021-10-26 05:50:00
# KQEJ             KQEJ  38.110000     128.03      220.0 2021-10-26 05:50:00
# ...               ...        ...        ...        ...                 ...
# SKRG             SKRG   6.170000     -75.42     2137.0 2021-10-26 20:00:00
# SKSP             SKSP  12.570000     -81.72       -2.0 2021-10-26 20:00:00
# SKBG             SKBG   7.130000     -73.18     1189.0 2021-10-26 20:00:00
# SKPE             SKPE   4.820000     -75.73     1346.0 2021-10-26 20:00:00
# KNJM             KNJM  34.670000     -77.02        7.0 2021-10-26 19:57:00
#
#             wind_direction  wind_speed  visibility current_wx1 current_wx2  \
# station_id
# KMJD                   0.0         0.0         NaN         NaN         NaN
# PAKU                  20.0        10.0    4828.032         -SN          BR
# KRYY                 320.0        11.0   16093.440         NaN         NaN
# KQEI                 180.0         2.0    9999.000         NaN         NaN
# KQEJ                 230.0         4.0    9999.000         NaN         NaN
# ...                    ...         ...         ...         ...         ...
# SKRG                 180.0         8.0    9999.000        VCSH         NaN
# SKSP                  70.0         7.0    9999.000         NaN         NaN
# SKBG                  10.0         5.0    9999.000        VCSH         NaN
# SKPE                 170.0         5.0    9999.000        VCSH         NaN
# KNJM                 280.0        10.0   16093.440         NaN         NaN
#
#             ... air_temperature dew_point_temperature  altimeter  \
# station_id  ...
# KMJD        ...            18.0                  17.0      29.97
# PAKU        ...            -2.0                  -2.0      29.20
# KRYY        ...            13.0                   8.0      29.93
# KQEI        ...            17.0                   6.0      30.08
# KQEJ        ...            17.0                   6.0      30.06
# ...         ...             ...                   ...        ...
# SKRG        ...            22.0                  14.0      30.21
# SKSP        ...            30.0                  23.0      29.83
# SKBG        ...            23.0                  20.0      29.91
# SKPE        ...            24.0                  17.0      30.00
# KNJM        ...            23.0                  11.0      29.62
#
#            current_wx1_symbol  current_wx2_symbol current_wx3_symbol  \
# station_id
# KMJD                        0                   0                  0
# PAKU                       71                  10                  0
# KRYY                        0                   0                  0
# KQEI                        0                   0                  0
# KQEJ                        0                   0                  0
# ...                       ...                 ...                ...
# SKRG                       16                   0                  0
# SKSP                        0                   0                  0
# SKBG                       16                   0                  0
# SKPE                       16                   0                  0
# KNJM                        0                   0                  0
#
#                                              remarks  \
# station_id
# KMJD                                             AO2
# PAKU
# KRYY        AO2 SLP125 T01330078 10200 20133 51013 $
# KQEI                                        A02 TSNO
# KQEJ                                        A02 TSNO
# ...                                              ...
# SKRG
# SKSP                                           A2985
# SKBG
# SKPE                                          VCSH/S
# KNJM                                             AO2
#
#            air_pressure_at_sea_level  eastward_wind  northward_wind
# station_id
# KMJD                         1015.18  -0.000000e+00       -0.000000
# PAKU                          989.14  -3.420201e+00       -9.396926
# KRYY                         1013.97   7.070664e+00       -8.426489
# KQEI                         1018.73  -2.449294e-16        2.000000
# KQEJ                         1018.02   3.064178e+00        2.571150
# ...                              ...            ...             ...
# SKRG                         1011.21  -9.797174e-16        8.000000
# SKSP                         1010.31  -6.577848e+00       -2.394141
# SKBG                         1007.47  -8.682409e-01       -4.924039
# SKPE                         1008.95  -8.682409e-01        4.924039
# KNJM                         1003.32   9.848078e+00       -1.736482
#
# [118888 rows x 30 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/26/v_0y9smd4yg7fq6t0q68qf0h00017d/T/ipykernel_12337/2911592343.py in <module>
# ----> 1 station_locs = metar_dataframe[["station_id","latitude","longitude"]].drop_duplicates()
#       2
#       3
#       4
#       5 display(station_locs)
#
# NameError: name 'metar_dataframe' is not defined

# %% [markdown]
# ## Rotate through Available Files

# %%
mydict = {'george': 16, 'amber': 19}
print(mydict)
print(list(mydict.keys())[list(mydict.values()).index(16)])  # Prints george
# Out:
# {'george': 16, 'amber': 19}
# george

# %%
####################################################
####################################################
####################################################
#
# Rotate through Available Files
#

file_time = model_start_datetime.strftime('%Y-%m-%d_%H')

TS_DIR    = WRF_ARCHIVE  + "./current_complete_run/STATION_TIME_SERIES/"

#
# Creating Graphics Directory
#

graphics_directory = WRF_IMAGES + "./current_complete_run/STATION_TIME_SERIES/"

print("Creating " + graphics_directory)

os.system("mkdir -pv " + graphics_directory )

#
# Start File Rotation
#

for station in available_time_series_list.iterrows():
    
    
    print(" ")
    
    print("============")



    ###################################################################
    #
    # Pull Station Data 
    #

    station_id     = station[1][0]
    grid_domain    = station[1][1]
    station_name   = station[1][2]
    station_lat    = station[1][3]
    station_lon    = station[1][4]

    #    
    ###################################################################
    

    
    station_data = metar_dataframe[metar_dataframe["station_id"]==station_id]

         
    def haversine(row):
        lon1 = station_lon
        lat1 = station_lat
        lon2 = row['longitude']
        lat2 = row['latitude']
        lon1, lat1, lon2, lat2 = map(np.radians, [lon1, lat1, lon2, lat2])
        dlon = lon2 - lon1 
        dlat = lat2 - lat1 
        a = np.sin(dlat/2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2)**2
        c = 2 * np.arcsin(np.sqrt(a)) 
        km = 6367 * c
        return km
    
    station_locs['distance'] = station_locs.apply(lambda row: haversine(row), axis=1)
    
    x=station_locs[ station_locs['distance'] == station_locs['distance'].min() ]

    try:
        weather_station_name = airport_database[x['station_id'][0]]["name"]+", "+airport_database[x['station_id'][0]]["subd"]
    except KeyError:
        weather_station_name = x['station_id'][0]
        
    
    print(station_id,station_name, x['station_id'][0],x['distance'][0],weather_station_name)
# Out:
# Creating /Users/wjc/GitHub/SD_Mines_WRF_REALTIME/./WEB_IMAGES/./current_complete_run/STATION_TIME_SERIES/
#
# ============
# KUNR Rapid City NWS, SD KRCA 12.240370056153777 Ellsworth Air Force Base, South Dakota
#
# ============
# KRCA Ellsworth AFB, SD KRCA 1.6296502395712364 Ellsworth Air Force Base, South Dakota
#
# ============
# KRAP Rapid City Arpt, SD KRAP 0.8409331432441511 Rapid City Regional Airport, South Dakota
#
# ============
# KUDX Rapid City, NEXRAD, SD KRAP 19.622317178372253 Rapid City Regional Airport, South Dakota
#
# ============
# KCUT Custer Arpt, SD KCUT 0.7958661898751643 Custer County Airport, South Dakota
#
# ============
# KSPF Clyde Ice Field, SD KSPF 1.7746789569246564 Black Hills Clyde Ice Field, South Dakota
#
# ============
# KEFC Belle Fourche Muni, SD KSPF 30.226595132411433 Black Hills Clyde Ice Field, South Dakota
#
# ============
# KW43 Hulett Arpt, WY KW43 0.8046661902614582 Hulett Municipal Airport, Wyoming
#
# ============
# KPHP Philip Arpt, SD KPHP 0.1368495222648345 Philip Airport, South Dakota
#
# ============
# KIEN Pine Ridge Arpt, SD KIEN 1.0132376449948546 Pine Ridge Airport, South Dakota
#
# ============
# KCDR Chadron Airport, NE KCDR 0.7947668278362362 Chadron Municipal Airport, Nebraska
#
# ============
# K4MC Moorcroft, WY KGCC 48.230772665066816 Gillette Campbell County Airport, Wyoming
#
# ============
# KD07 Faith Airport, SD KD07 0.23571779199038556 Faith Municipal Airport, South Dakota
#
# ============
# KGRN Gordon Muni, NE KIEN 37.521705712192 Pine Ridge Airport, South Dakota
#
# ============
# K2WX Buffalo, SD K2WX 0.5424897936727022 K2WX
#
# ============
# KGCC Gillette Arpt, WY KGCC 1.1851549539178123 Gillette Campbell County Airport, Wyoming
#
# ============
# KHEI Hettinger Arpt, ND KHEI 0.33337534042398165 Hettinger Municipal Airport, North Dakota
#
# ============
# KY22 Lemmon, SD KHEI 38.53300069880815 Hettinger Municipal Airport, North Dakota
#
# ============
# KLEM Lemmon Arpt, SD KHEI 43.48979263663136 Hettinger Municipal Airport, North Dakota
#
# ============
# KDGW Converse Co Arpt, WY KDGW 0.44450045389746407 Converse County Airport, Wyoming
#
# ============
# KAIA Alliance Arpt, NE KAIA 0.0 Alliance Municipal Airport, Nebraska
#
# ============
# K4DG Douglas, WY KDGW 5.5616416864629725 Converse County Airport, Wyoming
#
# ============
# KSIB Sibley Peak, WY KGUR 30.778077993259956 KGUR
#
# ============
# KPIR Pierre Arpt, SD KPIR 0.4893192575209878 Pierre Regional Airport, South Dakota
#
# ============
# KBPP Bowman Arpt, ND KBWW 10.10506548891033 KBWW
#
# ============
# KTOR Torrington Arpt, WY KTOR 1.1982572006944312 Torrington Municipal Airport, Wyoming
#
# ============
# KMIS Mission, SD KVTN 18.915391841560947 Miller Field, Nebraska
#
# ============
# KBFF Scottsbluff Arpt, NE KBFF 1.0814731495630028 Western Neb. Rgnl/William B. Heilig Airport, Nebraska
#
# ============
# KVTN Miller Field Arpt, NE KVTN 0.8890009077963419 Miller Field, Nebraska
#
# ============
# MUNS Munich School, ND KD55 33.21471377789889 Robertson Field, North Dakota

# %%
# Out:
# 'Rapid City Regional Airport'

# %%
airport_database
# Out:
# {'00AK': {'icao': '00AK',
#   'iata': '',
#   'name': 'Lowell Field',
#   'city': 'Anchor Point',
#   'subd': 'Alaska',
#   'country': 'US',
#   'elevation': 450.0,
#   'lat': 59.94919968,
#   'lon': -151.695999146,
#   'tz': 'America/Anchorage'},
#  '00AL': {'icao': '00AL',
#   'iata': '',
#   'name': 'Epps Airpark',
#   'city': 'Harvest',
#   'subd': 'Alabama',
#   'country': 'US',
#   'elevation': 820.0,
#   'lat': 34.8647994995,
#   'lon': -86.7703018188,
#   'tz': 'America/Chicago'},
#  '00AZ': {'icao': '00AZ',
#   'iata': '',
#   'name': 'Cordes Airport',
#   'city': 'Cordes',
#   'subd': 'Arizona',
#   'country': 'US',
#   'elevation': 3810.0,
#   'lat': 34.3055992126,
#   'lon': -112.1650009155,
#   'tz': 'America/Phoenix'},
#  '00CA': {'icao': '00CA',
#   'iata': '',
#   'name': 'Goldstone /Gts/ Airport',
#   'city': 'Barstow',
#   'subd': 'California',
#   'country': 'US',
#   'elevation': 3038.0,
#   'lat': 35.3504981995,
#   'lon': -116.888000488,
#   'tz': 'America/Los_Angeles'},
#  '00CO': {'icao': '00CO',
#   'iata': '',
#   'name': 'Cass Field',
#   'city': 'Briggsdale',
#   'subd': 'Colorado',
#   'country': 'US',
#   'elevation': 4830.0,
#   'lat': 40.6222000122,
#   'lon': -104.34400177,
#   'tz': 'America/Denver'},
#  '00FA': {'icao': '00FA',
#   'iata': '',
#   'name': 'Grass Patch Airport',
#   'city': 'Bushnell',
#   'subd': 'Florida',
#   'country': 'US',
#   'elevation': 53.0,
#   'lat': 28.6455001831,
#   'lon': -82.21900177,
#   'tz': 'America/New_York'},
#  '00FL': {'icao': '00FL',
#   'iata': '',
#   'name': 'River Oak Airport',
#   'city': 'Okeechobee',
#   'subd': 'Florida',
#   'country': 'US',
#   'elevation': 35.0,
#   'lat': 27.2308998108,
#   'lon': -80.9692001343,
#   'tz': 'America/New_York'},
#  '00GA': {'icao': '00GA',
#   'iata': '',
#   'name': 'Lt World Airport',
#   'city': 'Lithonia',
#   'subd': 'Georgia',
#   'country': 'US',
#   'elevation': 700.0,
#   'lat': 33.7675018311,
#   'lon': -84.0682983398,
#   'tz': 'America/New_York'},
#  '00ID': {'icao': '00ID',
#   'iata': '',
#   'name': 'Delta Shores Airport',
#   'city': 'Clark Fork',
#   'subd': 'Idaho',
#   'country': 'US',
#   'elevation': 2064.0,
#   'lat': 48.1453018188,
#   'lon': -116.2139968872,
#   'tz': 'America/Los_Angeles'},
#  '00IL': {'icao': '00IL',
#   'iata': '',
#   'name': 'Hammer Airport',
#   'city': 'Polo',
#   'subd': 'Illinois',
#   'country': 'US',
#   'elevation': 840.0,
#   'lat': 41.9784011841,
#   'lon': -89.5604019165,
#   'tz': 'America/Chicago'},
#  '00IS': {'icao': '00IS',
#   'iata': '',
#   'name': "Hayenga's Cant Find Farms Airport",
#   'city': 'Kings',
#   'subd': 'Illinois',
#   'country': 'US',
#   'elevation': 820.0,
#   'lat': 40.0256004333,
#   'lon': -89.1229019165,
#   'tz': 'America/Chicago'},
#  '00KS': {'icao': '00KS',
#   'iata': '',
#   'name': 'Hayden Farm Airport',
#   'city': 'Gardner',
#   'subd': 'Kansas',
#   'country': 'US',
#   'elevation': 1100.0,
#   'lat': 38.7277984619,
#   'lon': -94.9304962158,
#   'tz': 'America/Chicago'},
#  '00KY': {'icao': '00KY',
#   'iata': '',
#   'name': 'Robbins Roost Airport',
#   'city': 'Stanford',
#   'subd': 'Kentucky',
#   'country': 'US',
#   'elevation': 1265.0,
#   'lat': 37.4094009399,
#   'lon': -84.6196975708,
#   'tz': 'America/New_York'},
#  '00LS': {'icao': '00LS',
#   'iata': '',
#   'name': 'Lejeune Airport',
#   'city': 'Esterwood',
#   'subd': 'Louisiana',
#   'country': 'US',
#   'elevation': 12.0,
#   'lat': 30.1362991333,
#   'lon': -92.429397583,
#   'tz': 'America/Chicago'},
#  '00MD': {'icao': '00MD',
#   'iata': '',
#   'name': 'Slater Field',
#   'city': 'Federalsburg',
#   'subd': 'Maryland',
#   'country': 'US',
#   'elevation': 45.0,
#   'lat': 38.7570991516,
#   'lon': -75.7537994385,
#   'tz': 'America/New_York'},
#  '00MN': {'icao': '00MN',
#   'iata': '',
#   'name': 'Battle Lake Municipal Airport',
#   'city': 'Battle Lake',
#   'subd': 'Minnesota',
#   'country': 'US',
#   'elevation': 1365.0,
#   'lat': 46.2999992371,
#   'lon': -95.700302124,
#   'tz': 'America/Chicago'},
#  '00MO': {'icao': '00MO',
#   'iata': '',
#   'name': 'Cooper Flying Service Airport',
#   'city': 'Alba',
#   'subd': 'Missouri',
#   'country': 'US',
#   'elevation': 970.0,
#   'lat': 37.2028007507,
#   'lon': -94.412399292,
#   'tz': 'America/Chicago'},
#  '00MT': {'icao': '00MT',
#   'iata': '',
#   'name': 'Sands Ranch Airport',
#   'city': 'Havre',
#   'subd': 'Montana',
#   'country': 'US',
#   'elevation': 2600.0,
#   'lat': 48.5374984741,
#   'lon': -109.7050018311,
#   'tz': 'America/Denver'},
#  '00NC': {'icao': '00NC',
#   'iata': '',
#   'name': 'North Raleigh Airport',
#   'city': 'Louisburg',
#   'subd': 'North Carolina',
#   'country': 'US',
#   'elevation': 348.0,
#   'lat': 36.0852012634,
#   'lon': -78.3713989258,
#   'tz': 'America/New_York'},
#  '00NY': {'icao': '00NY',
#   'iata': '',
#   'name': 'Weiss Airfield',
#   'city': 'West Bloomfield',
#   'subd': 'New York',
#   'country': 'US',
#   'elevation': 1000.0,
#   'lat': 42.900100708,
#   'lon': -77.4997024536,
#   'tz': 'America/New_York'},
#  '00OH': {'icao': '00OH',
#   'iata': '',
#   'name': 'Exit 3 Airport',
#   'city': 'Wauseon',
#   'subd': 'Ohio',
#   'country': 'US',
#   'elevation': 785.0,
#   'lat': 41.5909004211,
#   'lon': -84.1421966553,
#   'tz': 'America/New_York'},
#  '00PN': {'icao': '00PN',
#   'iata': '',
#   'name': 'Ferrell Field',
#   'city': 'Mercer',
#   'subd': 'Pennsylvania',
#   'country': 'US',
#   'elevation': 1301.0,
#   'lat': 41.2995,
#   'lon': -80.211111,
#   'tz': 'America/New_York'},
#  '00PS': {'icao': '00PS',
#   'iata': '',
#   'name': 'Thomas Field',
#   'city': 'Loysville',
#   'subd': 'Pennsylvania',
#   'country': 'US',
#   'elevation': 815.0,
#   'lat': 40.3777999878,
#   'lon': -77.3653030396,
#   'tz': 'America/New_York'},
#  '00SC': {'icao': '00SC',
#   'iata': '',
#   'name': 'Flying O Airport',
#   'city': 'Sumter',
#   'subd': 'South Carolina',
#   'country': 'US',
#   'elevation': 150.0,
#   'lat': 34.0093994141,
#   'lon': -80.2671966553,
#   'tz': 'America/New_York'},
#  '00TN': {'icao': '00TN',
#   'iata': '',
#   'name': 'Ragsdale Road Airport',
#   'city': 'Manchester',
#   'subd': 'Tennessee',
#   'country': 'US',
#   'elevation': 1100.0,
#   'lat': 35.5158996582,
#   'lon': -85.9535980225,
#   'tz': 'America/Chicago'},
#  '00TS': {'icao': '00TS',
#   'iata': '',
#   'name': 'Alpine Range Airport',
#   'city': 'Everman',
#   'subd': 'Texas',
#   'country': 'US',
#   'elevation': 670.0,
#   'lat': 32.6076011658,
#   'lon': -97.2419967651,
#   'tz': 'America/Chicago'},
#  '00VA': {'icao': '00VA',
#   'iata': '',
#   'name': 'Vaughan Airport',
#   'city': 'Alton',
#   'subd': 'Virginia',
#   'country': 'US',
#   'elevation': 551.0,
#   'lat': 36.57600021,
#   'lon': -78.9991684,
#   'tz': 'America/New_York'},
#  '00VI': {'icao': '00VI',
#   'iata': '',
#   'name': 'Groundhog Mountain Airport',
#   'city': 'Hillsville',
#   'subd': 'Virginia',
#   'country': 'US',
#   'elevation': 2680.0,
#   'lat': 36.6632995605,
#   'lon': -80.49949646,
#   'tz': 'America/New_York'},
#  '00WA': {'icao': '00WA',
#   'iata': '',
#   'name': 'Howell Airport',
#   'city': 'Longbranch',
#   'subd': 'Washington',
#   'country': 'US',
#   'elevation': 150.0,
#   'lat': 47.1783981323,
#   'lon': -122.7720031738,
#   'tz': 'America/Los_Angeles'},
#  '00WI': {'icao': '00WI',
#   'iata': '',
#   'name': 'Northern Lite Airport',
#   'city': 'Waupaca',
#   'subd': 'Wisconsin',
#   'country': 'US',
#   'elevation': 860.0,
#   'lat': 44.3042984009,
#   'lon': -89.0501022339,
#   'tz': 'America/Chicago'},
#  '00WN': {'icao': '00WN',
#   'iata': '',
#   'name': 'Hawks Run Airport',
#   'city': 'Asotin',
#   'subd': 'Washington',
#   'country': 'US',
#   'elevation': 2900.0,
#   'lat': 46.25,
#   'lon': -117.2490005493,
#   'tz': 'America/Los_Angeles'},
#  '00WV': {'icao': '00WV',
#   'iata': '',
#   'name': 'Lazy J. Aerodrome',
#   'city': 'Beverly',
#   'subd': 'West Virginia',
#   'country': 'US',
#   'elevation': 2060.0,
#   'lat': 38.8288993835,
#   'lon': -79.8660964966,
#   'tz': 'America/New_York'},
#  '00XS': {'icao': '00XS',
#   'iata': '',
#   'name': 'L P Askew Farms Airport',
#   'city': "O'Donnell",
#   'subd': 'Texas',
#   'country': 'US',
#   'elevation': 3110.0,
#   'lat': 33.0334014893,
#   'lon': -101.9339981079,
#   'tz': 'America/Chicago'},
#  '01AL': {'icao': '01AL',
#   'iata': '',
#   'name': 'Ware Island Airport',
#   'city': 'Clanton',
#   'subd': 'Alabama',
#   'country': 'US',
#   'elevation': 344.0,
#   'lat': 32.9459991455,
#   'lon': -86.5139007568,
#   'tz': 'America/Chicago'},
#  '01CL': {'icao': '01CL',
#   'iata': '',
#   'name': 'Swansboro Country Airport',
#   'city': 'Placerville',
#   'subd': 'California',
#   'country': 'US',
#   'elevation': 2594.0,
#   'lat': 38.7999000549,
#   'lon': -120.7340011597,
#   'tz': 'America/Los_Angeles'},
#  '01FA': {'icao': '01FA',
#   'iata': '',
#   'name': 'Rybolt Ranch Airport',
#   'city': 'Orlando',
#   'subd': 'Florida',
#   'country': 'US',
#   'elevation': 55.0,
#   'lat': 28.5893993378,
#   'lon': -81.144203186,
#   'tz': 'America/New_York'},
#  '01FL': {'icao': '01FL',
#   'iata': '',
#   'name': 'Cedar Knoll Flying Ranch Airport',
#   'city': 'Geneva',
#   'subd': 'Florida',
#   'country': 'US',
#   'elevation': 19.0,
#   'lat': 28.7819004059,
#   'lon': -81.1592025757,
#   'tz': 'America/New_York'},
#  '01GE': {'icao': '01GE',
#   'iata': '',
#   'name': 'The Farm Airport',
#   'city': 'Wrightsville',
#   'subd': 'Georgia',
#   'country': 'US',
#   'elevation': 375.0,
#   'lat': 32.6744003296,
#   'lon': -82.7711029053,
#   'tz': 'America/New_York'},
#  '01IA': {'icao': '01IA',
#   'iata': '',
#   'name': 'Stender Airport',
#   'city': 'Maysville',
#   'subd': 'Iowa',
#   'country': 'US',
#   'elevation': 725.0,
#   'lat': 41.6610984802,
#   'lon': -90.7413024902,
#   'tz': 'America/Chicago'},
#  '01ID': {'icao': '01ID',
#   'iata': '',
#   'name': 'Lava Hot Springs Airport',
#   'city': 'Lava Hot Springs',
#   'subd': 'Idaho',
#   'country': 'US',
#   'elevation': 5268.0,
#   'lat': 42.6082000732,
#   'lon': -112.0319976807,
#   'tz': 'America/Boise'},
#  '01II': {'icao': '01II',
#   'iata': '',
#   'name': 'Myers Field',
#   'city': 'Lizton',
#   'subd': 'Indiana',
#   'country': 'US',
#   'elevation': 950.0,
#   'lat': 39.8849983215,
#   'lon': -86.5066986084,
#   'tz': 'America/Indiana/Indianapolis'},
#  '01IS': {'icao': '01IS',
#   'iata': '',
#   'name': 'William E. Koenig Airport',
#   'city': 'Dow',
#   'subd': 'Illinois',
#   'country': 'US',
#   'elevation': 670.0,
#   'lat': 39.0162010193,
#   'lon': -90.3181991577,
#   'tz': 'America/Chicago'},
#  '01KS': {'icao': '01KS',
#   'iata': '',
#   'name': 'Flying N Ranch Airport',
#   'city': 'Lost Springs',
#   'subd': 'Kansas',
#   'country': 'US',
#   'elevation': 1485.0,
#   'lat': 38.540599823,
#   'lon': -97.0033035278,
#   'tz': 'America/Chicago'},
#  '01LA': {'icao': '01LA',
#   'iata': '',
#   'name': 'Barham Airport',
#   'city': 'Oak Ridge',
#   'subd': 'Louisiana',
#   'country': 'US',
#   'elevation': 90.0,
#   'lat': 32.638999939,
#   'lon': -91.7736968994,
#   'tz': 'America/Chicago'},
#  '01LL': {'icao': '01LL',
#   'iata': '',
#   'name': 'Schumaier Restricted Landing Area',
#   'city': 'Pinckneyville',
#   'subd': 'Illinois',
#   'country': 'US',
#   'elevation': 555.0,
#   'lat': 38.1258010864,
#   'lon': -89.4638977051,
#   'tz': 'America/Chicago'},
#  '01LS': {'icao': '01LS',
#   'iata': '',
#   'name': 'Country Breeze Airport',
#   'city': 'Slaughter',
#   'subd': 'Louisiana',
#   'country': 'US',
#   'elevation': 125.0,
#   'lat': 30.7059993744,
#   'lon': -91.0774002075,
#   'tz': 'America/Chicago'},
#  '01MT': {'icao': '01MT',
#   'iata': '',
#   'name': 'Crystal Lakes Resort Airport',
#   'city': 'Fortine',
#   'subd': 'Montana',
#   'country': 'US',
#   'elevation': 3141.0,
#   'lat': 48.789100647,
#   'lon': -114.8799972534,
#   'tz': 'America/Denver'},
#  '01NC': {'icao': '01NC',
#   'iata': '',
#   'name': 'Topsail Airpark',
#   'city': 'Holly Ridge',
#   'subd': 'North Carolina',
#   'country': 'US',
#   'elevation': 65.0,
#   'lat': 34.4752998352,
#   'lon': -77.5813980103,
#   'tz': 'America/New_York'},
#  '01NE': {'icao': '01NE',
#   'iata': '',
#   'name': 'Detour Airport',
#   'city': 'Wellfleet',
#   'subd': 'Nebraska',
#   'country': 'US',
#   'elevation': 3000.0,
#   'lat': 40.8436012268,
#   'lon': -100.6529998779,
#   'tz': 'America/Chicago'},
#  '01NH': {'icao': '01NH',
#   'iata': '',
#   'name': 'Moore Airfield',
#   'city': 'Enfield',
#   'subd': 'New Hampshire',
#   'country': 'US',
#   'elevation': 835.0,
#   'lat': 43.6445007324,
#   'lon': -72.0869979858,
#   'tz': 'America/New_York'},
#  '01NM': {'icao': '01NM',
#   'iata': '',
#   'name': 'Champion Ranch Airport',
#   'city': 'Artesia',
#   'subd': 'New Mexico',
#   'country': 'US',
#   'elevation': 3630.0,
#   'lat': 33.008611,
#   'lon': -104.540278,
#   'tz': 'America/Denver'},
#  '01NV': {'icao': '01NV',
#   'iata': '',
#   'name': 'Lantana Ranch Airport',
#   'city': 'Yerington',
#   'subd': 'Nevada',
#   'country': 'US',
#   'elevation': 4600.0,
#   'lat': 38.7639007568,
#   'lon': -119.0270004272,
#   'tz': 'America/Los_Angeles'},
#  '01OK': {'icao': '01OK',
#   'iata': '',
#   'name': 'Lawrence Airport',
#   'city': 'Eakly',
#   'subd': 'Oklahoma',
#   'country': 'US',
#   'elevation': 1525.0,
#   'lat': 35.2944984436,
#   'lon': -98.6364974976,
#   'tz': 'America/Chicago'},
#  '01OR': {'icao': '01OR',
#   'iata': '',
#   'name': 'Red & White Flying Service Airport',
#   'city': 'Silver Lake',
#   'subd': 'Oregon',
#   'country': 'US',
#   'elevation': 4346.0,
#   'lat': 43.1193008423,
#   'lon': -121.0449981689,
#   'tz': 'America/Los_Angeles'},
#  '01PN': {'icao': '01PN',
#   'iata': '',
#   'name': 'Bierly(Personal Use) Airport',
#   'city': 'Bellefonte',
#   'subd': 'Pennsylvania',
#   'country': 'US',
#   'elevation': 960.0,
#   'lat': 40.9305992126,
#   'lon': -77.738899231,
#   'tz': 'America/New_York'},
#  '01PS': {'icao': '01PS',
#   'iata': '',
#   'name': "Nort's Resort Airport",
#   'city': 'Meshoppen',
#   'subd': 'Pennsylvania',
#   'country': 'US',
#   'elevation': 1040.0,
#   'lat': 41.5959014893,
#   'lon': -76.0296020508,
#   'tz': 'America/New_York'},
#  '01SC': {'icao': '01SC',
#   'iata': '',
#   'name': 'York Airport',
#   'city': 'York',
#   'subd': 'South Carolina',
#   'country': 'US',
#   'elevation': 779.0,
#   'lat': 35.0321006775,
#   'lon': -81.2527999878,
#   'tz': 'America/New_York'},
#  '01TE': {'icao': '01TE',
#   'iata': '',
#   'name': 'Smith Field',
#   'city': 'Forney',
#   'subd': 'Texas',
#   'country': 'US',
#   'elevation': 505.0,
#   'lat': 32.7375984192,
#   'lon': -96.4280014038,
#   'tz': 'America/Chicago'},
#  '01TN': {'icao': '01TN',
#   'iata': '',
#   'name': 'Colonial Air Park',
#   'city': 'Collierville',
#   'subd': 'Tennessee',
#   'country': 'US',
#   'elevation': 370.0,
#   'lat': 34.9958992004,
#   'lon': -89.7305984497,
#   'tz': 'America/Chicago'},
#  '01TX': {'icao': '01TX',
#   'iata': '',
#   'name': 'Mims Farm Ultralightport',
#   'city': 'Waxahachie',
#   'subd': 'Texas',
#   'country': 'US',
#   'elevation': 610.0,
#   'lat': 32.3875999451,
#   'lon': -96.8775024414,
#   'tz': 'America/Chicago'},
#  '01UT': {'icao': '01UT',
#   'iata': '',
#   'name': 'La Sal Junction Airport',
#   'city': 'La Sal',
#   'subd': 'Utah',
#   'country': 'US',
#   'elevation': 6000.0,
#   'lat': 38.3083000183,
#   'lon': -109.3960037231,
#   'tz': 'America/Denver'},
#  '01VA': {'icao': '01VA',
#   'iata': '',
#   'name': 'Pickles Airport',
#   'city': 'Berryville',
#   'subd': 'Virginia',
#   'country': 'US',
#   'elevation': 500.0,
#   'lat': 39.125,
#   'lon': -77.9250030518,
#   'tz': 'America/New_York'},
#  '01WI': {'icao': '01WI',
#   'iata': '',
#   'name': 'Prehn Cranberry Company Airport',
#   'city': 'Tomah',
#   'subd': 'Wisconsin',
#   'country': 'US',
#   'elevation': 930.0,
#   'lat': 44.0099983215,
#   'lon': -90.3891983032,
#   'tz': 'America/Chicago'},
#  '01WY': {'icao': '01WY',
#   'iata': '',
#   'name': 'Keyhole Airport',
#   'city': 'Moorcroft',
#   'subd': 'Wyoming',
#   'country': 'US',
#   'elevation': 4250.0,
#   'lat': 44.3471984863,
#   'lon': -104.8109970093,
#   'tz': 'America/Denver'},
#  '02AK': {'icao': '02AK',
#   'iata': '',
#   'name': 'Rustic Wilderness Airport',
#   'city': 'Willow',
#   'subd': 'Alaska',
#   'country': 'US',
#   'elevation': 190.0,
#   'lat': 61.8768997192,
#   'lon': -150.0980072021,
#   'tz': 'America/Anchorage'},
#  '02AL': {'icao': '02AL',
#   'iata': '',
#   'name': 'Bass Field',
#   'city': 'Foley',
#   'subd': 'Alabama',
#   'country': 'US',
#   'elevation': 61.0,
#   'lat': 30.3715000153,
#   'lon': -87.7643966675,
#   'tz': 'America/Chicago'},
#  '02AR': {'icao': '02AR',
#   'iata': '',
#   'name': 'Three Rivers Airport',
#   'city': 'Little Rock',
#   'subd': 'Arkansas',
#   'country': 'US',
#   'elevation': 264.0,
#   'lat': 34.8224449158,
#   'lon': -92.4444198608,
#   'tz': 'America/Chicago'},
#  '02AZ': {'icao': '02AZ',
#   'iata': '',
#   'name': 'Winchester Farm Airstrip',
#   'city': 'Willcox',
#   'subd': 'Arizona',
#   'country': 'US',
#   'elevation': 4200.0,
#   'lat': 32.3763999939,
#   'lon': -109.93699646,
#   'tz': 'America/Phoenix'},
#  '02CD': {'icao': '02CD',
#   'iata': '',
#   'name': 'Shannon Field',
#   'city': 'Clarksdale',
#   'subd': 'Mississippi',
#   'country': 'US',
#   'elevation': 165.0,
#   'lat': 34.1296005249,
#   'lon': -90.5240020752,
#   'tz': 'America/Chicago'},
#  '02CL': {'icao': '02CL',
#   'iata': '',
#   'name': 'Conover Air Lodge Airport',
#   'city': 'Frazier Park',
#   'subd': 'California',
#   'country': 'US',
#   'elevation': 5160.0,
#   'lat': 34.761100769,
#   'lon': -119.0589981079,
#   'tz': 'America/Los_Angeles'},
#  '02CO': {'icao': '02CO',
#   'iata': '',
#   'name': 'Mc Cullough Airport',
#   'city': 'Monte Vista',
#   'subd': 'Colorado',
#   'country': 'US',
#   'elevation': 7615.0,
#   'lat': 37.6432991028,
#   'lon': -106.04699707,
#   'tz': 'America/Denver'},
#  '02FA': {'icao': '02FA',
#   'iata': '',
#   'name': 'Osborn Airfield',
#   'city': 'Groveland',
#   'subd': 'Florida',
#   'country': 'US',
#   'elevation': 121.0,
#   'lat': 28.5266990662,
#   'lon': -81.8748016357,
#   'tz': 'America/New_York'},
#  '02FL': {'icao': '02FL',
#   'iata': '',
#   'name': 'Cuchens Airport',
#   'city': 'Defuniak Springs',
#   'subd': 'Florida',
#   'country': 'US',
#   'elevation': 215.0,
#   'lat': 30.642778,
#   'lon': -86.123889,
#   'tz': 'America/Chicago'},
#  '02GA': {'icao': '02GA',
#   'iata': '',
#   'name': 'Doug Bolton Field',
#   'city': 'Commerce',
#   'subd': 'Georgia',
#   'country': 'US',
#   'elevation': 884.0,
#   'lat': 34.2025985718,
#   'lon': -83.4290008545,
#   'tz': 'America/New_York'},
#  '02GE': {'icao': '02GE',
#   'iata': '',
#   'name': 'Etowah Fields Airport',
#   'city': 'Euharlee',
#   'subd': 'Georgia',
#   'country': 'US',
#   'elevation': 710.0,
#   'lat': 34.1753005981,
#   'lon': -84.9244003296,
#   'tz': 'America/New_York'},
#  '02ID': {'icao': '02ID',
#   'iata': '',
#   'name': 'Morgan Ranch Airport',
#   'city': 'Cascade',
#   'subd': 'Idaho',
#   'country': 'US',
#   'elevation': 5634.0,
#   'lat': 44.5555000305,
#   'lon': -115.3050003052,
#   'tz': 'America/Boise'},
#  '02II': {'icao': '02II',
#   'iata': '',
#   'name': 'King Ultralightport',
#   'city': 'Westfield',
#   'subd': 'Indiana',
#   'country': 'US',
#   'elevation': 925.0,
#   'lat': 40.0623016357,
#   'lon': -86.2105026245,
#   'tz': 'America/Indiana/Indianapolis'},
#  '02IN': {'icao': '02IN',
#   'iata': '',
#   'name': 'Diamond P. Field',
#   'city': 'Muncie',
#   'subd': 'Indiana',
#   'country': 'US',
#   'elevation': 904.0,
#   'lat': 40.2089004517,
#   'lon': -85.540802002,
#   'tz': 'America/Indiana/Indianapolis'},
#  '02KS': {'icao': '02KS',
#   'iata': '',
#   'name': 'Jmj Landing Airport',
#   'city': 'St Marys',
#   'subd': 'Kansas',
#   'country': 'US',
#   'elevation': 1170.0,
#   'lat': 39.2221984863,
#   'lon': -96.0552978516,
#   'tz': 'America/Chicago'},
#  '02ME': {'icao': '02ME',
#   'iata': '',
#   'name': 'Old Acton Airfield',
#   'city': 'Acton',
#   'subd': 'Maine',
#   'country': 'US',
#   'elevation': 700.0,
#   'lat': 43.5373001099,
#   'lon': -70.929397583,
#   'tz': 'America/New_York'},
#  '02MI': {'icao': '02MI',
#   'iata': '',
#   'name': 'Fairplains Airpark',
#   'city': 'Greenville',
#   'subd': 'Michigan',
#   'country': 'US',
#   'elevation': 850.0,
#   'lat': 43.1571006775,
#   'lon': -85.1484985352,
#   'tz': 'America/Detroit'},
#  '02MN': {'icao': '02MN',
#   'iata': '',
#   'name': 'Greenbush Municipal Airport',
#   'city': 'Greenbush',
#   'subd': 'Minnesota',
#   'country': 'US',
#   'elevation': 1070.0,
#   'lat': 48.6833000183,
#   'lon': -96.1920013428,
#   'tz': 'America/Chicago'},
#  '02MO': {'icao': '02MO',
#   'iata': '',
#   'name': 'Troy Airpark',
#   'city': 'Troy',
#   'subd': 'Missouri',
#   'country': 'US',
#   'elevation': 650.0,
#   'lat': 39.0499992371,
#   'lon': -91.0335006714,
#   'tz': 'America/Chicago'},
#  '02MS': {'icao': '02MS',
#   'iata': '',
#   'name': 'Watts Field',
#   'city': 'Rochdale',
#   'subd': 'Mississippi',
#   'country': 'US',
#   'elevation': 153.0,
#   'lat': 34.1001014709,
#   'lon': -90.8468017578,
#   'tz': 'America/Chicago'},
#  '02MT': {'icao': '02MT',
#   'iata': '',
#   'name': 'Barrett Field',
#   'city': 'Cascade',
#   'subd': 'Montana',
#   'country': 'US',
#   'elevation': 3350.0,
#   'lat': 47.2374000549,
#   'lon': -111.7419967651,
#   'tz': 'America/Denver'},
#  '02MU': {'icao': '02MU',
#   'iata': '',
#   'name': 'Timber Line Airpark',
#   'city': 'Cassville',
#   'subd': 'Missouri',
#   'country': 'US',
#   'elevation': 1550.0,
#   'lat': 36.6542015076,
#   'lon': -93.7974014282,
#   'tz': 'America/Chicago'},
#  '02NE': {'icao': '02NE',
#   'iata': '',
#   'name': 'Benes Service Airport',
#   'city': 'Valparaiso',
#   'subd': 'Nebraska',
#   'country': 'US',
#   'elevation': 1550.0,
#   'lat': 41.0745010376,
#   'lon': -96.9045028687,
#   'tz': 'America/Chicago'},
#  '02NV': {'icao': '02NV',
#   'iata': '',
#   'name': 'Paiute Meadows Airport',
#   'city': 'Winnemucca',
#   'subd': 'Nevada',
#   'country': 'US',
#   'elevation': 4443.0,
#   'lat': 41.3032989502,
#   'lon': -118.5979995728,
#   'tz': 'America/Los_Angeles'},
#  '02OH': {'icao': '02OH',
#   'iata': '',
#   'name': 'Zimmerman Airport',
#   'city': 'Fremont',
#   'subd': 'Ohio',
#   'country': 'US',
#   'elevation': 614.0,
#   'lat': 41.3763999939,
#   'lon': -83.0832977295,
#   'tz': 'America/New_York'},
#  '02OI': {'icao': '02OI',
#   'iata': '',
#   'name': 'Murtha Airport',
#   'city': 'Conneaut',
#   'subd': 'Ohio',
#   'country': 'US',
#   'elevation': 950.0,
#   'lat': 41.8019981384,
#   'lon': -80.5653991699,
#   'tz': 'America/New_York'},
#  '02OR': {'icao': '02OR',
#   'iata': '',
#   'name': 'Rowena Dell Airport',
#   'city': 'The Dalles',
#   'subd': 'Oregon',
#   'country': 'US',
#   'elevation': 705.0,
#   'lat': 45.6814994812,
#   'lon': -121.3160018921,
#   'tz': 'America/Los_Angeles'},
#  '02PR': {'icao': '02PR',
#   'iata': '',
#   'name': 'Cuylers Airport',
#   'city': 'Vega Baja',
#   'subd': 'Vega Baja',
#   'country': 'PR',
#   'elevation': 15.0,
#   'lat': 18.4533004761,
#   'lon': -66.366897583,
#   'tz': 'America/Puerto_Rico'},
#  '02PS': {'icao': '02PS',
#   'iata': '',
#   'name': 'Hughes Ultralightport',
#   'city': 'Tioga',
#   'subd': 'Pennsylvania',
#   'country': 'US',
#   'elevation': 1700.0,
#   'lat': 41.9006004333,
#   'lon': -77.2303009033,
#   'tz': 'America/New_York'},
#  '02SC': {'icao': '02SC',
#   'iata': '',
#   'name': 'Harpers Airport',
#   'city': 'Estill',
#   'subd': 'South Carolina',
#   'country': 'US',
#   'elevation': 111.0,
#   'lat': 32.7584991455,
#   'lon': -81.2248001099,
#   'tz': 'America/New_York'},
#  '02TN': {'icao': '02TN',
#   'iata': '',
#   'name': 'Ellis Field',
#   'city': 'Murfreesboro',
#   'subd': 'Tennessee',
#   'country': 'US',
#   'elevation': 840.0,
#   'lat': 35.7806015015,
#   'lon': -86.584197998,
#   'tz': 'America/Chicago'},
#  '02TX': {'icao': '02TX',
#   'iata': '',
#   'name': 'The Palms At Kitty Hawk Airport',
#   'city': 'New Home',
#   'subd': 'Texas',
#   'country': 'US',
#   'elevation': 3235.0,
#   'lat': 33.3704032898,
#   'lon': -101.92288208,
#   'tz': 'America/Chicago'},
#  '02UT': {'icao': '02UT',
#   'iata': '',
#   'name': 'Lucin Airport',
#   'city': 'Lucin',
#   'subd': 'Utah',
#   'country': 'US',
#   'elevation': 4412.0,
#   'lat': 41.3662986755,
#   'lon': -113.8430023193,
#   'tz': 'America/Denver'},
#  '02VA': {'icao': '02VA',
#   'iata': '',
#   'name': 'The Greenhouse Airport',
#   'city': 'Culpeper',
#   'subd': 'Virginia',
#   'country': 'US',
#   'elevation': 320.0,
#   'lat': 38.4356994629,
#   'lon': -77.8572006226,
#   'tz': 'America/New_York'},
#  '02WA': {'icao': '02WA',
#   'iata': '',
#   'name': 'Cawleys South Prairie Airport',
#   'city': 'South Prairie',
#   'subd': 'Washington',
#   'country': 'US',
#   'elevation': 690.0,
#   'lat': 47.1523017883,
#   'lon': -122.09400177,
#   'tz': 'America/Los_Angeles'},
#  '02WI': {'icao': '02WI',
#   'iata': '',
#   'name': 'Beer Airport',
#   'city': 'Hudson',
#   'subd': 'Wisconsin',
#   'country': 'US',
#   'elevation': 920.0,
#   'lat': 45.0318984985,
#   'lon': -92.6557998657,
#   'tz': 'America/Chicago'},
#  '02WN': {'icao': '02WN',
#   'iata': '',
#   'name': 'Fowler Field',
#   'city': 'Tonasket',
#   'subd': 'Washington',
#   'country': 'US',
#   'elevation': 2150.0,
#   'lat': 48.7458000183,
#   'lon': -119.3190002441,
#   'tz': 'America/Los_Angeles'},
#  '02XS': {'icao': '02XS',
#   'iata': '',
#   'name': 'Seidel Ranch Airport',
#   'city': 'Elroy',
#   'subd': 'Texas',
#   'country': 'US',
#   'elevation': 510.0,
#   'lat': 30.1476993561,
#   'lon': -97.6628036499,
#   'tz': 'America/Chicago'},
#  '03AZ': {'icao': '03AZ',
#   'iata': '',
#   'name': 'Thompson International Aviation Airport',
#   'city': 'Hereford',
#   'subd': 'Arizona',
#   'country': 'US',
#   'elevation': 4275.0,
#   'lat': 31.4333992004,
#   'lon': -110.0839996338,
#   'tz': 'America/Phoenix'},
#  '03CO': {'icao': '03CO',
#   'iata': '',
#   'name': 'Kugel-Strong Airport',
#   'city': 'Platteville',
#   'subd': 'Colorado',
#   'country': 'US',
#   'elevation': 4950.0,
#   'lat': 40.2125015259,
#   'lon': -104.744003296,
#   'tz': 'America/Denver'},
#  '03FA': {'icao': '03FA',
#   'iata': '',
#   'name': 'Lake Persimmon Airstrip',
#   'city': 'Lake Placid',
#   'subd': 'Florida',
#   'country': 'US',
#   'elevation': 70.0,
#   'lat': 27.353099823,
#   'lon': -81.4080963135,
#   'tz': 'America/New_York'},
#  '03FD': {'icao': '03FD',
#   'iata': '',
#   'name': 'Tharpe Airport',
#   'city': 'Bonifay',
#   'subd': 'Florida',
#   'country': 'US',
#   'elevation': 115.0,
#   'lat': 30.8288002014,
#   'lon': -85.7310028076,
#   'tz': 'America/New_York'},
#  '03IA': {'icao': '03IA',
#   'iata': '',
#   'name': 'East Field',
#   'city': 'Montezuma',
#   'subd': 'Iowa',
#   'country': 'US',
#   'elevation': 954.0,
#   'lat': 41.5819015503,
#   'lon': -92.4613037109,
#   'tz': 'America/Chicago'},
#  '03ID': {'icao': '03ID',
#   'iata': '',
#   'name': 'Flying Y Ranch Airport',
#   'city': 'Council',
#   'subd': 'Idaho',
#   'country': 'US',
#   'elevation': 3180.0,
#   'lat': 44.7943000793,
#   'lon': -116.5329971313,
#   'tz': 'America/Boise'},
#  '03II': {'icao': '03II',
#   'iata': '',
#   'name': 'Davis Field Ultralightport',
#   'city': 'Mount Vernon',
#   'subd': 'Indiana',
#   'country': 'US',
#   'elevation': 465.0,
#   'lat': 37.9620018005,
#   'lon': -87.7789001465,
#   'tz': 'America/Chicago'},
#  '03IL': {'icao': '03IL',
#   'iata': '',
#   'name': 'Wix Airport',
#   'city': 'Monee',
#   'subd': 'Illinois',
#   'country': 'US',
#   'elevation': 750.0,
#   'lat': 41.4023017883,
#   'lon': -87.8167037964,
#   'tz': 'America/Chicago'},
#  '03IN': {'icao': '03IN',
#   'iata': '',
#   'name': 'Heinzman Airport',
#   'city': 'Arcadia',
#   'subd': 'Indiana',
#   'country': 'US',
#   'elevation': 850.0,
#   'lat': 40.1800003052,
#   'lon': -86.0124969482,
#   'tz': 'America/Indiana/Indianapolis'},
#  '03KY': {'icao': '03KY',
#   'iata': '',
#   'name': 'Flying H Farms Airport',
#   'city': 'Henderson',
#   'subd': 'Kentucky',
#   'country': 'US',
#   'elevation': 385.0,
#   'lat': 37.7916984558,
#   'lon': -87.5413970947,
#   'tz': 'America/Chicago'},
#  '03MA': {'icao': '03MA',
#   'iata': '',
#   'name': 'Hadley Airport',
#   'city': 'Hadley',
#   'subd': 'Massachusetts',
#   'country': 'US',
#   'elevation': 150.0,
#   'lat': 42.3931007385,
#   'lon': -72.5520019531,
#   'tz': 'America/New_York'},
#  '03ME': {'icao': '03ME',
#   'iata': '',
#   'name': 'Maple Ridge Airport',
#   'city': 'Harrison',
#   'subd': 'Maine',
#   'country': 'US',
#   'elevation': 556.0,
#   'lat': 44.0842018127,
#   'lon': -70.6272964478,
#   'tz': 'America/New_York'},
#  '03MN': {'icao': '03MN',
#   'iata': '',
#   'name': 'Nauerth Land Ranch Airport',
#   'city': 'Lakefield',
#   'subd': 'Minnesota',
#   'country': 'US',
#   'elevation': 1435.0,
#   'lat': 43.6251983643,
#   'lon': -95.2247009277,
#   'tz': 'America/Chicago'},
#  '03MO': {'icao': '03MO',
#   'iata': '',
#   'name': 'Cahoochie Airport',
#   'city': 'Urbana',
#   'subd': 'Missouri',
#   'country': 'US',
#   'elevation': 1010.0,
#   'lat': 37.8844985962,
#   'lon': -93.1315994263,
#   'tz': 'America/Chicago'},
#  '03MT': {'icao': '03MT',
#   'iata': '',
#   'name': 'Cascade Airport',
#   'city': 'Cascade',
#   'subd': 'Montana',
#   'country': 'US',
#   'elevation': 3580.0,
#   'lat': 47.2708015442,
#   'lon': -111.7220001221,
#   'tz': 'America/Denver'},
#  '03MU': {'icao': '03MU',
#   'iata': '',
#   'name': 'Mc Donnell Airport',
#   'city': 'Archie',
#   'subd': 'Missouri',
#   'country': 'US',
#   'elevation': 874.0,
#   'lat': 38.4925003052,
#   'lon': -94.4124984741,
#   'tz': 'America/Chicago'},
#  '03NC': {'icao': '03NC',
#   'iata': '',
#   'name': 'Pilots Ridge Airport',
#   'city': 'Carolina Beach',
#   'subd': 'North Carolina',
#   'country': 'US',
#   'elevation': 35.0,
#   'lat': 34.1043014526,
#   'lon': -77.9041976929,
#   'tz': 'America/New_York'},
#  '03ND': {'icao': '03ND',
#   'iata': '',
#   'name': 'Olafson Brothers Airport',
#   'city': 'Edinburg',
#   'subd': 'North Dakota',
#   'country': 'US',
#   'elevation': 1045.0,
#   'lat': 48.6263999939,
#   'lon': -97.8290023804,
#   'tz': 'America/Chicago'},
#  '03NE': {'icao': '03NE',
#   'iata': '',
#   'name': 'Hyde Ranch Airport',
#   'city': 'Comstock',
#   'subd': 'Nebraska',
#   'country': 'US',
#   'elevation': 2430.0,
#   'lat': 41.5463981628,
#   'lon': -99.331199646,
#   'tz': 'America/Chicago'},
#  '03NV': {'icao': '03NV',
#   'iata': '',
#   'name': 'Llama Ranch Airport',
#   'city': 'Ruby Valley',
#   'subd': 'Nevada',
#   'country': 'US',
#   'elevation': 6120.0,
#   'lat': 40.584400177,
#   'lon': -115.297996521,
#   'tz': 'America/Los_Angeles'},
#  '03NY': {'icao': '03NY',
#   'iata': '',
#   'name': 'Talmage Field',
#   'city': 'Riverhead',
#   'subd': 'New York',
#   'country': 'US',
#   'elevation': 95.0,
#   'lat': 40.9584007263,
#   'lon': -72.716796875,
#   'tz': 'America/New_York'},
#  '03OH': {'icao': '03OH',
#   'iata': '',
#   'name': 'Gibbs Field',
#   'city': 'Fremont',
#   'subd': 'Ohio',
#   'country': 'US',
#   'elevation': 580.0,
#   'lat': 41.4183998108,
#   'lon': -83.0174026489,
#   'tz': 'America/New_York'},
#  '03OK': {'icao': '03OK',
#   'iata': '',
#   'name': 'Sahoma Lake Airport',
#   'city': 'Sapulpa',
#   'subd': 'Oklahoma',
#   'country': 'US',
#   'elevation': 890.0,
#   'lat': 36.0411987305,
#   'lon': -96.1613998413,
#   'tz': 'America/Chicago'},
#  '03OR': {'icao': '03OR',
#   'iata': '',
#   'name': 'Powwatka Ridge Airport',
#   'city': 'Troy',
#   'subd': 'Oregon',
#   'country': 'US',
#   'elevation': 3340.0,
#   'lat': 45.8554000854,
#   'lon': -117.4840011597,
#   'tz': 'America/Los_Angeles'},
#  '03PS': {'icao': '03PS',
#   'iata': '',
#   'name': "Ziggy's Field",
#   'city': 'Bellefonte',
#   'subd': 'Pennsylvania',
#   'country': 'US',
#   'elevation': 1050.0,
#   'lat': 40.8499984741,
#   'lon': -77.9056015015,
#   'tz': 'America/New_York'},
#  '03TA': {'icao': '03TA',
#   'iata': '',
#   'name': 'Gay Hill Farm Airport',
#   'city': 'Gay Hill',
#   'subd': 'Texas',
#   'country': 'US',
#   'elevation': 505.0,
#   'lat': 30.2626991272,
#   'lon': -96.5001983643,
#   'tz': 'America/Chicago'},
#  '03TE': {'icao': '03TE',
#   'iata': '',
#   'name': 'Barronena Ranch Airport',
#   'city': 'Hebbronville',
#   'subd': 'Texas',
#   'country': 'US',
#   'elevation': 600.0,
#   'lat': 27.4911003113,
#   'lon': -98.6695022583,
#   'tz': 'America/Chicago'},
#  '03UT': {'icao': '03UT',
#   'iata': '',
#   'name': 'A Z Minerals Corporation Airport',
#   'city': 'Mexican Hat',
#   'subd': 'Utah',
#   'country': 'US',
#   'elevation': 5315.0,
#   'lat': 37.1208000183,
#   'lon': -109.986000061,
#   'tz': 'America/Denver'},
#  '03WA': {'icao': '03WA',
#   'iata': '',
#   'name': 'Spangle Field',
#   'city': 'Spangle',
#   'subd': 'Washington',
#   'country': 'US',
#   'elevation': 2440.0,
#   'lat': 47.4081993103,
#   'lon': -117.3720016479,
#   'tz': 'America/Los_Angeles'},
#  '03WI': {'icao': '03WI',
#   'iata': '',
#   'name': 'Zink Airport',
#   'city': 'Berlin',
#   'subd': 'Wisconsin',
#   'country': 'US',
#   'elevation': 880.0,
#   'lat': 44.0275001526,
#   'lon': -88.880897522,
#   'tz': 'America/Chicago'},
#  '03WN': {'icao': '03WN',
#   'iata': '',
#   'name': 'Aerostone Ranch Airport',
#   'city': 'Goldendale',
#   'subd': 'Washington',
#   'country': 'US',
#   'elevation': 2320.0,
#   'lat': 45.875,
#   'lon': -120.6699981689,
#   'tz': 'America/Los_Angeles'},
#  '03XS': {'icao': '03XS',
#   'iata': '',
#   'name': 'Creekside Airport',
#   'city': 'Mertzon',
#   'subd': 'Texas',
#   'country': 'US',
#   'elevation': 2100.0,
#   'lat': 31.3180999756,
#   'lon': -100.7539978027,
#   'tz': 'America/Chicago'},
#  '04AZ': {'icao': '04AZ',
#   'iata': '',
#   'name': 'Chinle Airport',
#   'city': 'Chinle',
#   'subd': 'Arizona',
#   'country': 'US',
#   'elevation': 5515.0,
#   'lat': 36.1542015076,
#   'lon': -109.5510025024,
#   'tz': 'America/Denver'},
#  '04CA': {'icao': '04CA',
#   'iata': '',
#   'name': 'Gray Butte Field',
#   'city': 'Palmdale',
#   'subd': 'California',
#   'country': 'US',
#   'elevation': 3020.0,
#   'lat': 34.5638999939,
#   'lon': -117.6750030518,
#   'tz': 'America/Los_Angeles'},
#  '04CL': {'icao': '04CL',
#   'iata': '',
#   'name': "Hunt's Sky Ranch Airport",
#   'city': 'Julian',
#   'subd': 'California',
#   'country': 'US',
#   'elevation': 2310.0,
#   'lat': 33.0816993713,
#   'lon': -116.4410018921,
#   'tz': 'America/Los_Angeles'},
#  '04FA': {'icao': '04FA',
#   'iata': '',
#   'name': 'Richards Field',
#   'city': 'Homestead',
#   'subd': 'Florida',
#   'country': 'US',
#   'elevation': 9.0,
#   'lat': 25.5587005615,
#   'lon': -80.5150985718,
#   'tz': 'America/New_York'},
#  '04FL': {'icao': '04FL',
#   'iata': '',
#   'name': 'Cross Creek Farms Airport',
#   'city': 'Ormond',
#   'subd': 'Florida',
#   'country': 'US',
#   'elevation': 30.0,
#   'lat': 29.2394008636,
#   'lon': -81.2220001221,
#   'tz': 'America/New_York'},
#  '04IA': {'icao': '04IA',
#   'iata': '',
#   'name': 'Middlekoop Airport',
#   'city': 'Packwood',
#   'subd': 'Iowa',
#   'country': 'US',
#   'elevation': 801.0,
#   'lat': 41.0882987976,
#   'lon': -92.0546035767,
#   'tz': 'America/Chicago'},
#  '04ID': {'icao': '04ID',
#   'iata': '',
#   'name': 'Lanham Field',
#   'city': 'Emmett',
#   'subd': 'Idaho',
#   'country': 'US',
#   'elevation': 2343.0,
#   'lat': 43.8777008057,
#   'lon': -116.5370025635,
#   'tz': 'America/Boise'},
#  '04II': {'icao': '04II',
#   'iata': '',
#   'name': 'Turkey Run Airport',
#   'city': 'New Haven',
#   'subd': 'Indiana',
#   'country': 'US',
#   'elevation': 765.0,
#   'lat': 41.1305999756,
#   'lon': -84.994102478,
#   'tz': 'America/Indiana/Indianapolis'},
#  '04IL': {'icao': '04IL',
#   'iata': '',
#   'name': 'Schertz Aerial Service - Hudson Airport',
#   'city': 'Hudson',
#   'subd': 'Illinois',
#   'country': 'US',
#   'elevation': 755.0,
#   'lat': 40.6375007629,
#   'lon': -89.0070037842,
#   'tz': 'America/Chicago'},
#  '04IS': {'icao': '04IS',
#   'iata': '',
#   'name': 'Van Gorder Airport',
#   'city': 'Mansfield',
#   'subd': 'Illinois',
#   'country': 'US',
#   'elevation': 728.0,
#   'lat': 40.1786003113,
#   'lon': -88.5690002441,
#   'tz': 'America/Chicago'},
#  '04KY': {'icao': '04KY',
#   'iata': '',
#   'name': 'Natchez Trace Farm Airport',
#   'city': 'Hiseville',
#   'subd': 'Kentucky',
#   'country': 'US',
#   'elevation': 710.0,
#   'lat': 37.1351013184,
#   'lon': -85.7893981934,
#   'tz': 'America/Chicago'},
#  '04LL': {'icao': '04LL',
#   'iata': '',
#   'name': 'Brunner Airport',
#   'city': 'West Dundee',
#   'subd': 'Illinois',
#   'country': 'US',
#   'elevation': 750.0,
#   'lat': 42.136100769,
#   'lon': -88.2875976563,
#   'tz': 'America/Chicago'},
#  '04ME': {'icao': '04ME',
#   'iata': '',
#   'name': 'Beech Hill Airport',
#   'city': 'Mercer',
#   'subd': 'Maine',
#   'country': 'US',
#   'elevation': 625.0,
#   'lat': 44.6666984558,
#   'lon': -69.8938980103,
#   'tz': 'America/New_York'},
#  '04MI': {'icao': '04MI',
#   'iata': '',
#   'name': 'Rapids Airway Airport',
#   'city': 'Eaton Rapids',
#   'subd': 'Michigan',
#   'country': 'US',
#   'elevation': 880.0,
#   'lat': 42.5345001221,
#   'lon': -84.6283035278,
#   'tz': 'America/Detroit'},
#  '04MN': {'icao': '04MN',
#   'iata': '',
#   'name': 'Helblad Airport',
#   'city': 'Kelliher',
#   'subd': 'Minnesota',
#   'country': 'US',
#   'elevation': 1195.0,
#   'lat': 47.9858016968,
#   'lon': -94.6868972778,
#   'tz': 'America/Chicago'},
#  '04MO': {'icao': '04MO',
#   'iata': '',
#   'name': 'Airpark Private Airport',
#   'city': 'Vandalia',
#   'subd': 'Missouri',
#   'country': 'US',
#   'elevation': 767.0,
#   'lat': 39.3012008667,
#   'lon': -91.451499939,
#   'tz': 'America/Chicago'},
#  '04MS': {'icao': '04MS',
#   'iata': '',
#   'name': "Nick's Flying Service Inc Airport",
#   'city': 'Rolling Fork',
#   'subd': 'Mississippi',
#   'country': 'US',
#   'elevation': 100.0,
#   'lat': 32.9396018982,
#   'lon': -90.8373031616,
#   'tz': 'America/Chicago'},
#  '04MT': {'icao': '04MT',
#   'iata': '',
#   'name': 'Pluhar Airport',
#   'city': 'Cohagen',
#   'subd': 'Montana',
#   'country': 'US',
#   'elevation': 2715.0,
#   'lat': 47.1374977778,
#   'lon': -106.488095,
#   'tz': 'America/Denver'},
#  '04NE': {'icao': '04NE',
#   'iata': '',
#   'name': 'Mc Connell Field Airport',
#   'city': 'Sarben',
#   'subd': 'Nebraska',
#   'country': 'US',
#   'elevation': 3035.0,
#   'lat': 41.1599998474,
#   'lon': -101.299003601,
#   'tz': 'America/Denver'},
#  '04NJ': {'icao': '04NJ',
#   'iata': '',
#   'name': 'Emmanuel Airport',
#   'city': 'Elmer',
#   'subd': 'New Jersey',
#   'country': 'US',
#   'elevation': 155.0,
#   'lat': 39.5968017578,
#   'lon': -75.2334976196,
#   'tz': 'America/New_York'},
#  '04NV': {'icao': '04NV',
#   'iata': '',
#   'name': 'Kingston Ranch Airport',
#   'city': 'Sandy Valley',
#   'subd': 'California',
#   'country': 'US',
#   'elevation': 2620.0,
#   'lat': 35.7555007935,
#   'lon': -115.665000916,
#   'tz': 'America/Los_Angeles'},
#  '04NY': {'icao': '04NY',
#   'iata': '',
#   'name': 'Klaverack Airport',
#   'city': 'Hudson',
#   'subd': 'New York',
#   'country': 'US',
#   'elevation': 250.0,
#   'lat': 42.262298584,
#   'lon': -73.6961975098,
#   'tz': 'America/New_York'},
#  '04OH': {'icao': '04OH',
#   'iata': '',
#   'name': 'Bossow Airport',
#   'city': 'Garrettsville',
#   'subd': 'Ohio',
#   'country': 'US',
#   'elevation': 1080.0,
#   'lat': 41.2476997375,
#   'lon': -81.1007003784,
#   'tz': 'America/New_York'},
#  '04OR': {'icao': '04OR',
#   'iata': '',
#   'name': 'Collins Landing Strip',
#   'city': 'Mitchell',
#   'subd': 'Oregon',
#   'country': 'US',
#   'elevation': 1500.0,
#   'lat': 44.7499008179,
#   'lon': -120.200996399,
#   'tz': 'America/Los_Angeles'},
#  '04TN': {'icao': '04TN',
#   'iata': '',
#   'name': 'Hensley Airpark',
#   'city': 'Chuckey',
#   'subd': 'Tennessee',
#   'country': 'US',
#   'elevation': 1430.0,
#   'lat': 36.1833000183,
#   'lon': -82.6789016724,
#   'tz': 'America/New_York'},
#  '04TX': {'icao': '04TX',
#   'iata': '',
#   'name': 'Pocock Airport',
#   'city': 'China Spring',
#   'subd': 'Texas',
#   'country': 'US',
#   'elevation': 565.0,
#   'lat': 31.7322006226,
#   'lon': -97.3688964844,
#   'tz': 'America/Chicago'},
#  '04UT': {'icao': '04UT',
#   'iata': '',
#   'name': 'Navajo Mountain Airport',
#   'city': 'Navajo Mountain Trdng Post',
#   'subd': 'Utah',
#   'country': 'US',
#   'elevation': 6160.0,
#   'lat': 37.0083007812,
#   'lon': -110.794998169,
#   'tz': 'America/Denver'},
#  '04VG': {'icao': '04VG',
#   'iata': '',
#   'name': 'Manquin Flight Park Ultralightport',
#   'city': 'Manquin',
#   'subd': 'Virginia',
#   'country': 'US',
#   'elevation': 50.0,
#   'lat': 37.7144012451,
#   'lon': -77.2117996216,
#   'tz': 'America/New_York'},
#  '04VT': {'icao': '04VT',
#   'iata': '',
#   'name': 'Lightning Bolt Field Airport',
#   'city': 'Cabot',
#   'subd': 'Vermont',
#   'country': 'US',
#   'elevation': 2156.0,
#   'lat': 44.4011001587,
#   'lon': -72.2636032104,
#   'tz': 'America/New_York'},
#  '04WA': {'icao': '04WA',
#   'iata': '',
#   'name': 'Ox Meadows Airport',
#   'city': 'Spokane',
#   'subd': 'Washington',
#   'country': 'US',
#   'elevation': 2345.0,
#   'lat': 47.5817985535,
#   'lon': -117.43699646,
#   'tz': 'America/Los_Angeles'},
#  '04WI': {'icao': '04WI',
#   'iata': '',
#   'name': 'Dutch Gap Airstrip',
#   'city': 'Bristol',
#   'subd': 'Wisconsin',
#   'country': 'US',
#   'elevation': 760.0,
#   'lat': 42.523399353,
#   'lon': -88.0167007446,
#   'tz': 'America/Chicago'},
#  '04WN': {'icao': '04WN',
#   'iata': '',
#   'name': 'Stillwater Creek Airport',
#   'city': 'Royal City',
#   'subd': 'Washington',
#   'country': 'US',
#   'elevation': 1510.0,
#   'lat': 46.963889,
#   'lon': -119.641667,
#   'tz': 'America/Los_Angeles'},
#  '05AK': {'icao': '05AK',
#   'iata': '',
#   'name': 'Wasilla Creek Airpark',
#   'city': 'Palmer',
#   'subd': 'Alaska',
#   'country': 'US',
#   'elevation': 620.0,
#   'lat': 61.66830063,
#   'lon': -149.1880035,
#   'tz': 'America/Anchorage'},
#  '05AR': {'icao': '05AR',
#   'iata': '',
#   'name': 'Ozark Skies Airpark',
#   'city': 'Kingston',
#   'subd': 'Arkansas',
#   'country': 'US',
#   'elevation': 1900.0,
#   'lat': 36.000633,
#   'lon': -93.57025,
#   'tz': 'America/Chicago'},
#  '05CL': {'icao': '05CL',
#   'iata': '',
#   'name': 'Pope Valley Airport',
#   'city': 'Pope Valley',
#   'subd': 'California',
#   'country': 'US',
#   'elevation': 618.0,
#   'lat': 38.6106987,
#   'lon': -122.39099884,
#   'tz': 'America/Los_Angeles'},
#  '05CO': {'icao': '05CO',
#   'iata': '',
#   'name': 'Rancho De Aereo Airport',
#   'city': 'Mead',
#   'subd': 'Colorado',
#   'country': 'US',
#   'elevation': 4978.0,
#   'lat': 40.2149839,
#   'lon': -104.9844228,
#   'tz': 'America/Denver'},
#  '05FA': {'icao': '05FA',
#   'iata': '',
#   'name': "Melanie's Airport",
#   'city': 'Florala',
#   'subd': 'Florida',
#   'country': 'US',
#   'elevation': 295.0,
#   'lat': 30.9188995361,
#   'lon': -86.2182998657,
#   'tz': 'America/Chicago'},
#  '05FL': {'icao': '05FL',
#   'iata': '',
#   'name': 'Charlton Strip',
#   'city': 'La Belle',
#   'subd': 'Florida',
#   'country': 'US',
#   'elevation': 36.0,
#   'lat': 26.5230998993,
#   'lon': -81.4083023071,
#   'tz': 'America/New_York'},
#  '05GA': {'icao': '05GA',
#   'iata': '',
#   'name': 'Raju Airport',
#   'city': 'Richland',
#   'subd': 'Georgia',
#   'country': 'US',
#   'elevation': 625.0,
#   'lat': 32.0713996887,
#   'lon': -84.7144012451,
#   'tz': 'America/New_York'},
#  '05IA': {'icao': '05IA',
#   'iata': '',
#   'name': 'Spotts Field',
#   'city': 'Nora Springs',
#   'subd': 'Iowa',
#   'country': 'US',
#   'elevation': 1155.0,
#   'lat': 43.1375007629,
#   'lon': -93.0682983398,
#   'tz': 'America/Chicago'},
#  '05ID': {'icao': '05ID',
#   'iata': '',
#   'name': 'Running Creek Ranch Airport',
#   'city': 'Grangeville',
#   'subd': 'Idaho',
#   'country': 'US',
#   'elevation': 2969.0,
#   'lat': 45.914100647,
#   'lon': -114.8359985352,
#   'tz': 'America/Los_Angeles'},
#  '05II': {'icao': '05II',
#   'iata': '',
#   'name': 'Reichhart Airport',
#   'city': 'New Haven',
#   'subd': 'Indiana',
#   'country': 'US',
#   'elevation': 795.0,
#   'lat': 41.0287017822,
#   'lon': -84.9972000122,
#   'tz': 'America/Indiana/Indianapolis'},
#  '05IL': {'icao': '05IL',
#   'iata': '',
#   'name': 'Classic Landings Airport',
#   'city': 'Bonfield',
#   'subd': 'Illinois',
#   'country': 'US',
#   'elevation': 635.0,
#   'lat': 41.1567001343,
#   'lon': -88.0167007446,
#   'tz': 'America/Chicago'},
#  '05IN': {'icao': '05IN',
#   'iata': '',
#   'name': 'Cooper Airport',
#   'city': 'Belleville',
#   'subd': 'Indiana',
#   'country': 'US',
#   'elevation': 860.0,
#   'lat': 39.641998291,
#   'lon': -86.5042037964,
#   'tz': 'America/Indiana/Indianapolis'},
#  '05IS': {'icao': '05IS',
#   'iata': '',
#   'name': 'Hardy Airport',
#   'city': 'Mount Auburn',
#   'subd': 'Illinois',
#   'country': 'US',
#   'elevation': 605.0,
#   'lat': 39.7258987427,
#   'lon': -89.263999939,
#   'tz': 'America/Chicago'},
#  '05KS': {'icao': '05KS',
#   'iata': '',
#   'name': 'Darbro Field',
#   'city': 'Elk City',
#   'subd': 'Kansas',
#   'country': 'US',
#   'elevation': 945.0,
#   'lat': 37.2662010193,
#   'lon': -95.959197998,
#   'tz': 'America/Chicago'},
#  '05KY': {'icao': '05KY',
#   'iata': '',
#   'name': 'Cartersville Airport',
#   'city': 'Berea',
#   'subd': 'Kentucky',
#   'country': 'US',
#   'elevation': 1070.0,
#   'lat': 37.53689957,
#   'lon': -84.40720367,
#   'tz': 'America/New_York'},
#  '05LA': {'icao': '05LA',
#   'iata': '',
#   'name': "Greg's Flying Service Airport",
#   'city': 'Baskin',
#   'subd': 'Louisiana',
#   'country': 'US',
#   'elevation': 76.0,
#   'lat': 32.2653007507,
#   'lon': -91.6977996826,
#   'tz': 'America/Chicago'},
#  '05LS': {'icao': '05LS',
#   'iata': '',
#   'name': 'Grass Roots Airport',
#   'city': 'Alexandria',
#   'subd': 'Louisiana',
#   'country': 'US',
#   'elevation': 83.0,
#   'lat': 31.252199173,
#   'lon': -92.4757995605,
#   'tz': 'America/Chicago'},
#  '05MD': {'icao': '05MD',
#   'iata': '',
#   'name': 'Breezecroft Airport',
#   'city': 'Chestertown',
#   'subd': 'Maryland',
#   'country': 'US',
#   'elevation': 20.0,
#   'lat': 39.2500991821,
#   'lon': -76.2052001953,
#   'tz': 'America/New_York'},
#  '05ME': {'icao': '05ME',
#   'iata': '',
#   'name': 'Drisko Airport',
#   'city': 'Jonesboro',
#   'subd': 'Maine',
#   'country': 'US',
#   'elevation': 70.0,
#   'lat': 44.6570014954,
#   'lon': -67.5591964722,
#   'tz': 'America/New_York'},
#  '05NE': {'icao': '05NE',
#   'iata': '',
#   'name': 'Mc Kay Airport',
#   'city': 'Spalding',
#   'subd': 'Nebraska',
#   'country': 'US',
#   'elevation': 2010.0,
#   'lat': 41.7221984863,
#   'lon': -98.3089981079,
#   'tz': 'America/Chicago'},
#  '05OI': {'icao': '05OI',
#   'iata': '',
#   'name': 'Dorlon Airpark',
#   'city': 'Columbia Station',
#   'subd': 'Ohio',
#   'country': 'US',
#   'elevation': 830.0,
#   'lat': 41.2883987427,
#   'lon': -81.962600708,
#   'tz': 'America/New_York'},
#  '05OK': {'icao': '05OK',
#   'iata': '',
#   'name': 'Hawk Haven Airport',
#   'city': 'Crescent',
#   'subd': 'Oklahoma',
#   'country': 'US',
#   'elevation': 1075.0,
#   'lat': 35.8534011841,
#   'lon': -97.5674972534,
#   'tz': 'America/Chicago'},
#  '05OR': {'icao': '05OR',
#   'iata': '',
#   'name': 'Peacock Ranch Airport',
#   'city': 'Enterprise',
#   'subd': 'Oregon',
#   'country': 'US',
#   'elevation': 3500.0,
#   'lat': 45.4415016174,
#   'lon': -117.3509979248,
#   'tz': 'America/Los_Angeles'},
#  '05PS': {'icao': '05PS',
#   'iata': '',
#   'name': 'Mills Brothers Airport',
#   'city': 'Burnt Cabins',
#   'subd': 'Pennsylvania',
#   'country': 'US',
#   'elevation': 1210.0,
#   'lat': 40.1427993774,
#   'lon': -77.8619003296,
#   'tz': 'America/New_York'},
#  '05TA': {'icao': '05TA',
#   'iata': '',
#   'name': 'Brandes Air Field',
#   'city': 'Sealy',
#   'subd': 'Texas',
#   'country': 'US',
#   'elevation': 276.0,
#   'lat': 29.8090991974,
#   'lon': -96.2650985718,
#   'tz': 'America/Chicago'},
#  '05TE': {'icao': '05TE',
#   'iata': '',
#   'name': 'Hilde-Griff Field',
#   'city': 'Georgetown',
#   'subd': 'Texas',
#   'country': 'US',
#   'elevation': 950.0,
#   'lat': 30.7220993042,
#   'lon': -97.7913970947,
#   'tz': 'America/Chicago'},
#  '05TS': {'icao': '05TS',
#   'iata': '',
#   'name': 'Dew Drop Airport',
#   'city': 'Justin',
#   'subd': 'Texas',
#   'country': 'US',
#   'elevation': 750.0,
#   'lat': 33.1292991638,
#   'lon': -97.3585968018,
#   'tz': 'America/Chicago'},
#  '05TX': {'icao': '05TX',
#   'iata': '',
#   'name': "Circle 'A' Ranch Airport",
#   'city': 'Blum',
#   'subd': 'Texas',
#   'country': 'US',
#   'elevation': 608.0,
#   'lat': 32.1291999817,
#   'lon': -97.4041976929,
#   'tz': 'America/Chicago'},
#  '05UT': {'icao': '05UT',
#   'iata': '',
#   'name': 'Oljato Airport',
#   'city': 'Oljato',
#   'subd': 'Utah',
#   'country': 'US',
#   'elevation': 4838.0,
#   'lat': 37.0332984924,
#   'lon': -110.3170013428,
#   'tz': 'America/Denver'},
#  '05VA': {'icao': '05VA',
#   'iata': '',
#   'name': 'Providence Airport',
#   'city': 'Farmville',
#   'subd': 'Virginia',
#   'country': 'US',
#   'elevation': 445.0,
#   'lat': 37.2242012024,
#   'lon': -78.4186019897,
#   'tz': 'America/New_York'},
#  '05WI': {'icao': '05WI',
#   'iata': '',
#   'name': 'Ames Private Airport',
#   'city': 'Darien',
#   'subd': 'Wisconsin',
#   'country': 'US',
#   'elevation': 958.0,
#   'lat': 42.6511001587,
#   'lon': -88.7459030151,
#   'tz': 'America/Chicago'},
#  '05WN': {'icao': '05WN',
#   'iata': '',
#   'name': 'Flat Creek Field',
#   'city': 'Kettle Falls',
#   'subd': 'Washington',
#   'country': 'US',
#   'elevation': 1570.0,
#   'lat': 48.702222,
#   'lon': -118.0475,
#   'tz': 'America/Los_Angeles'},
#  '05XS': {'icao': '05XS',
#   'iata': '',
#   'name': 'Johnson Memorial Airport',
#   'city': 'Wilmot',
#   'subd': 'Arkansas',
#   'country': 'US',
#   'elevation': 105.0,
#   'lat': 33.0792999268,
#   'lon': -91.5431976318,
#   'tz': 'America/Chicago'},
#  '06AK': {'icao': '06AK',
#   'iata': '',
#   'name': 'June Lake Airpark',
#   'city': 'Wasilla',
#   'subd': 'Alaska',
#   'country': 'US',
#   'elevation': 425.0,
#   'lat': 61.627619,
#   'lon': -149.575331,
#   'tz': 'America/Anchorage'},
#  '06AR': {'icao': '06AR',
#   'iata': '',
#   'name': 'Bondair Airport',
#   'city': 'Higden',
#   'subd': 'Arkansas',
#   'country': 'US',
#   'elevation': 499.0,
#   'lat': 35.5444984436,
#   'lon': -92.1848983765,
#   'tz': 'America/Chicago'},
#  '06CO': {'icao': '06CO',
#   'iata': '',
#   'name': 'Jecan Airport',
#   'city': 'Branson',
#   'subd': 'Colorado',
#   'country': 'US',
#   'elevation': 5100.0,
#   'lat': 37.3875007629,
#   'lon': -103.6910018921,
#   'tz': 'America/Denver'},
#  '06FA': {'icao': '06FA',
#   'iata': '',
#   'name': 'William P Gwinn Airport',
#   'city': 'Jupiter',
#   'subd': 'Florida',
#   'country': 'US',
#   'elevation': 28.0,
#   'lat': 26.9083995819,
#   'lon': -80.3289031982,
#   'tz': 'America/New_York'},
#  '06FD': {'icao': '06FD',
#   'iata': '',
#   'name': 'Grass Roots Airpark',
# ...
#   'name': 'Sexton Airport',
#   'city': 'Newberry',
#   'subd': 'South Carolina',
#   'country': 'US',
#   'elevation': 593.0,
#   'lat': 34.353833,
#   'lon': -81.802358,
#   'tz': 'America/New_York'},
#  '19TA': {'icao': '19TA',
#   'iata': '',
#   'name': 'Lagrone Ranch Airport',
#   'city': 'Mc Clendon-Chisholm',
#   'subd': 'Texas',
#   'country': 'US',
#   'elevation': 567.0,
#   'lat': 32.8222999573,
#   'lon': -96.4169006348,
#   'tz': 'America/Chicago'},
#  '19TE': {'icao': '19TE',
#   'iata': '',
#   'name': 'Cut and Shoot Airport',
#   'city': 'Conroe',
#   'subd': 'Texas',
#   'country': 'US',
#   'elevation': 170.0,
#   'lat': 30.3169002533,
#   'lon': -95.3335037231,
#   'tz': 'America/Chicago'},
#  '19TN': {'icao': '19TN',
#   'iata': '',
#   'name': 'Ferraraccio Field',
#   'city': 'Clarksville',
#   'subd': 'Tennessee',
#   'country': 'US',
#   'elevation': 620.0,
#   'lat': 36.4994010925,
#   'lon': -87.1902999878,
#   'tz': 'America/Chicago'},
#  '19TX': {'icao': '19TX',
#   'iata': '',
#   'name': 'Woody Mc Clellan Ranch Airport',
#   'city': 'Temple',
#   'subd': 'Texas',
#   'country': 'US',
#   'elevation': 690.0,
#   'lat': 31.238199234,
#   'lon': -97.5141983032,
#   'tz': 'America/Chicago'},
#  '19VA': {'icao': '19VA',
#   'iata': '',
#   'name': 'Flying W Airport',
#   'city': 'St. Paul',
#   'subd': 'Virginia',
#   'country': 'US',
#   'elevation': 1760.0,
#   'lat': 36.8897018433,
#   'lon': -82.2977981567,
#   'tz': 'America/New_York'},
#  '19WA': {'icao': '19WA',
#   'iata': '',
#   'name': 'Key Way Airport',
#   'city': 'Stevenson',
#   'subd': 'Washington',
#   'country': 'US',
#   'elevation': 972.0,
#   'lat': 45.7196006775,
#   'lon': -121.8860015869,
#   'tz': 'America/Los_Angeles'},
#  '19WI': {'icao': '19WI',
#   'iata': '',
#   'name': 'Erickson Field',
#   'city': 'Prairie Farm',
#   'subd': 'Wisconsin',
#   'country': 'US',
#   'elevation': 1180.0,
#   'lat': 45.1952018738,
#   'lon': -92.0570983887,
#   'tz': 'America/Chicago'},
#  '19XS': {'icao': '19XS',
#   'iata': '',
#   'name': 'Draggintail Acres Airport',
#   'city': 'Maypearl',
#   'subd': 'Texas',
#   'country': 'US',
#   'elevation': 585.0,
#   'lat': 32.2971992493,
#   'lon': -97.0868988037,
#   'tz': 'America/Chicago'},
#  '1AK1': {'icao': '1AK1',
#   'iata': '',
#   'name': 'Crevice Creek Airport',
#   'city': 'Crevice Creek',
#   'subd': 'Alaska',
#   'country': 'US',
#   'elevation': 840.0,
#   'lat': 67.3729019165,
#   'lon': -152.0160064697,
#   'tz': 'America/Anchorage'},
#  '1AK2': {'icao': '1AK2',
#   'iata': '',
#   'name': 'Crosswind Lake Airport',
#   'city': 'Crosswind Lake',
#   'subd': 'Alaska',
#   'country': 'US',
#   'elevation': 2125.0,
#   'lat': 62.4009017944,
#   'lon': -146.0130004883,
#   'tz': 'America/Anchorage'},
#  '1AK4': {'icao': '1AK4',
#   'iata': '',
#   'name': 'Kenai River Airpark',
#   'city': 'Soldotna',
#   'subd': 'Alaska',
#   'country': 'US',
#   'elevation': 200.0,
#   'lat': 60.5242004395,
#   'lon': -150.7519989014,
#   'tz': 'America/Anchorage'},
#  '1AK6': {'icao': '1AK6',
#   'iata': '',
#   'name': 'Talachulitna River Airport',
#   'city': 'Sketna',
#   'subd': 'Alaska',
#   'country': 'US',
#   'elevation': 282.0,
#   'lat': 61.8527984619,
#   'lon': -151.4080047607,
#   'tz': 'America/Anchorage'},
#  '1AK8': {'icao': '1AK8',
#   'iata': '',
#   'name': 'Talaheim Airport',
#   'city': 'Skwentna',
#   'subd': 'Alaska',
#   'country': 'US',
#   'elevation': 610.0,
#   'lat': 61.6768989563,
#   'lon': -151.3869934082,
#   'tz': 'America/Anchorage'},
#  '1AL2': {'icao': '1AL2',
#   'iata': '',
#   'name': 'Tri-L Acres Airport',
#   'city': 'Columbiana',
#   'subd': 'Alabama',
#   'country': 'US',
#   'elevation': 580.0,
#   'lat': 33.2486000061,
#   'lon': -86.5975036621,
#   'tz': 'America/Chicago'},
#  '1AL4': {'icao': '1AL4',
#   'iata': '',
#   'name': 'Elsanor Airport',
#   'city': 'Robertsdale',
#   'subd': 'Alabama',
#   'country': 'US',
#   'elevation': 180.0,
#   'lat': 30.5447006226,
#   'lon': -87.5594024658,
#   'tz': 'America/Chicago'},
#  '1AL5': {'icao': '1AL5',
#   'iata': '',
#   'name': 'Berry Field',
#   'city': 'Loxley',
#   'subd': 'Alabama',
#   'country': 'US',
#   'elevation': 170.0,
#   'lat': 30.6364002228,
#   'lon': -87.7478027344,
#   'tz': 'America/Chicago'},
#  '1AL8': {'icao': '1AL8',
#   'iata': '',
#   'name': 'Moore Field',
#   'city': 'Moody',
#   'subd': 'Alabama',
#   'country': 'US',
#   'elevation': 730.0,
#   'lat': 33.6110992432,
#   'lon': -86.4744033813,
#   'tz': 'America/Chicago'},
#  '1AR0': {'icao': '1AR0',
#   'iata': '',
#   'name': 'Breckenridge Airport',
#   'city': 'Beedeville',
#   'subd': 'Arkansas',
#   'country': 'US',
#   'elevation': 221.0,
#   'lat': 35.3987007141,
#   'lon': -91.1334991455,
#   'tz': 'America/Chicago'},
#  '1AR1': {'icao': '1AR1',
#   'iata': '',
#   'name': 'Walls Airport',
#   'city': 'Coy',
#   'subd': 'Arkansas',
#   'country': 'US',
#   'elevation': 215.0,
#   'lat': 34.5271987915,
#   'lon': -91.8727035522,
#   'tz': 'America/Chicago'},
#  '1AR2': {'icao': '1AR2',
#   'iata': '',
#   'name': 'Taylor Airstrip',
#   'city': 'Des Arc',
#   'subd': 'Arkansas',
#   'country': 'US',
#   'elevation': 208.0,
#   'lat': 34.9868011475,
#   'lon': -91.5503005981,
#   'tz': 'America/Chicago'},
#  '1AR3': {'icao': '1AR3',
#   'iata': '',
#   'name': 'Bob Norman Airstrip',
#   'city': 'Des Arc',
#   'subd': 'Arkansas',
#   'country': 'US',
#   'elevation': 208.0,
#   'lat': 34.9732017517,
#   'lon': -91.5260009766,
#   'tz': 'America/Chicago'},
#  '1AR4': {'icao': '1AR4',
#   'iata': '',
#   'name': 'Foggy River Airport',
#   'city': 'Elkins',
#   'subd': 'Arkansas',
#   'country': 'US',
#   'elevation': 1240.0,
#   'lat': 36.0178985596,
#   'lon': -94.0184020996,
#   'tz': 'America/Chicago'},
#  '1AR5': {'icao': '1AR5',
#   'iata': '',
#   'name': 'Cherokee Strip',
#   'city': 'Gentry',
#   'subd': 'Arkansas',
#   'country': 'US',
#   'elevation': 1194.0,
#   'lat': 36.2994003296,
#   'lon': -94.5847015381,
#   'tz': 'America/Chicago'},
#  '1AR6': {'icao': '1AR6',
#   'iata': '',
#   'name': 'Diamond Bluff Airport',
#   'city': 'Greers Ferry',
#   'subd': 'Arkansas',
#   'country': 'US',
#   'elevation': 1000.0,
#   'lat': 35.5032997131,
#   'lon': -92.1967010498,
#   'tz': 'America/Chicago'},
#  '1AR8': {'icao': '1AR8',
#   'iata': '',
#   'name': 'Flying W Air Park Inc Airport',
#   'city': 'Lavaca',
#   'subd': 'Arkansas',
#   'country': 'US',
#   'elevation': 420.0,
#   'lat': 35.3256988525,
#   'lon': -94.1867980957,
#   'tz': 'America/Chicago'},
#  '1AR9': {'icao': '1AR9',
#   'iata': '',
#   'name': 'Country Air Estates Airport',
#   'city': 'Lonoke',
#   'subd': 'Arkansas',
#   'country': 'US',
#   'elevation': 250.0,
#   'lat': 34.8138999939,
#   'lon': -92.0,
#   'tz': 'America/Chicago'},
#  '1AZ0': {'icao': '1AZ0',
#   'iata': '',
#   'name': 'Mobile Airport',
#   'city': 'Mobile',
#   'subd': 'Arizona',
#   'country': 'US',
#   'elevation': 1261.0,
#   'lat': 33.1119003296,
#   'lon': -112.2689971924,
#   'tz': 'America/Phoenix'},
#  '1AZ2': {'icao': '1AZ2',
#   'iata': '',
#   'name': 'Paradise Air Park',
#   'city': 'Tolleson',
#   'subd': 'Arizona',
#   'country': 'US',
#   'elevation': 1015.0,
#   'lat': 33.4117012024,
#   'lon': -112.1819992065,
#   'tz': 'America/Phoenix'},
#  '1AZ8': {'icao': '1AZ8',
#   'iata': '',
#   'name': 'Willow Springs Ranch Airport',
#   'city': 'Bullhead City',
#   'subd': 'Arizona',
#   'country': 'US',
#   'elevation': 3750.0,
#   'lat': 35.2957992554,
#   'lon': -114.3730010986,
#   'tz': 'America/Phoenix'},
#  '1CA1': {'icao': '1CA1',
#   'iata': '',
#   'name': 'Belridge Strip',
#   'city': 'South Belridge',
#   'subd': 'California',
#   'country': 'US',
#   'elevation': 575.0,
#   'lat': 35.4679985046,
#   'lon': -119.7220001221,
#   'tz': 'America/Los_Angeles'},
#  '1CA4': {'icao': '1CA4',
#   'iata': '',
#   'name': 'Aha-Quin Airport',
#   'city': 'Blythe',
#   'subd': 'California',
#   'country': 'US',
#   'elevation': 300.0,
#   'lat': 33.8694992065,
#   'lon': -114.5270004272,
#   'tz': 'America/Los_Angeles'},
#  '1CA6': {'icao': '1CA6',
#   'iata': '',
#   'name': 'On the Rocks Airport',
#   'city': 'Alpine',
#   'subd': 'California',
#   'country': 'US',
#   'elevation': 2650.0,
#   'lat': 32.7650985718,
#   'lon': -116.7229995728,
#   'tz': 'America/Los_Angeles'},
#  '1CD1': {'icao': '1CD1',
#   'iata': '',
#   'name': 'Reed Airport',
#   'city': 'Nunn',
#   'subd': 'Colorado',
#   'country': 'US',
#   'elevation': 5350.0,
#   'lat': 40.6902999878,
#   'lon': -104.8669967651,
#   'tz': 'America/Denver'},
#  '1CD2': {'icao': '1CD2',
#   'iata': '',
#   'name': 'Tonga Airport',
#   'city': 'Platteville',
#   'subd': 'Colorado',
#   'country': 'US',
#   'elevation': 4925.0,
#   'lat': 40.1671981812,
#   'lon': -104.7929992676,
#   'tz': 'America/Denver'},
#  '1CD4': {'icao': '1CD4',
#   'iata': '',
#   'name': 'Eagle Soaring Airport',
#   'city': 'Steam Boat Springs',
#   'subd': 'Colorado',
#   'country': 'US',
#   'elevation': 6600.0,
#   'lat': 40.5093002319,
#   'lon': -106.9430007935,
#   'tz': 'America/Denver'},
#  '1CL1': {'icao': '1CL1',
#   'iata': '',
#   'name': 'Little Buttes Antique Airfield',
#   'city': 'Lancaster',
#   'subd': 'California',
#   'country': 'US',
#   'elevation': 2433.0,
#   'lat': 34.7941017151,
#   'lon': -118.2779998779,
#   'tz': 'America/Los_Angeles'},
#  '1CL2': {'icao': '1CL2',
#   'iata': '',
#   'name': 'Pontious Airport',
#   'city': 'Mojave',
#   'subd': 'California',
#   'country': 'US',
#   'elevation': 2610.0,
#   'lat': 34.9425010681,
#   'lon': -118.1699981689,
#   'tz': 'America/Los_Angeles'},
#  '1CO2': {'icao': '1CO2',
#   'iata': '',
#   'name': 'Williams Ranch Airport',
#   'city': 'Norwood',
#   'subd': 'Colorado',
#   'country': 'US',
#   'elevation': 6842.0,
#   'lat': 38.1624984741,
#   'lon': -108.3399963379,
#   'tz': 'America/Denver'},
#  '1CO3': {'icao': '1CO3',
#   'iata': '',
#   'name': 'Bellmore Farms Airport',
#   'city': 'Nunn',
#   'subd': 'Colorado',
#   'country': 'US',
#   'elevation': 5225.0,
#   'lat': 40.7041015625,
#   'lon': -104.797996521,
#   'tz': 'America/Denver'},
#  '1CO4': {'icao': '1CO4',
#   'iata': '',
#   'name': 'Clifford Field',
#   'city': 'Olathe',
#   'subd': 'Colorado',
#   'country': 'US',
#   'elevation': 5560.0,
#   'lat': 38.5750007629,
#   'lon': -107.9589996338,
#   'tz': 'America/Denver'},
#  '1CO5': {'icao': '1CO5',
#   'iata': '',
#   'name': 'Melon Field',
#   'city': 'Rocky Ford',
#   'subd': 'Colorado',
#   'country': 'US',
#   'elevation': 4260.0,
#   'lat': 38.0153007507,
#   'lon': -103.6989974976,
#   'tz': 'America/Denver'},
#  '1CO7': {'icao': '1CO7',
#   'iata': '',
#   'name': 'Dodsworth Airport',
#   'city': 'Salida',
#   'subd': 'Colorado',
#   'country': 'US',
#   'elevation': 7480.0,
#   'lat': 38.551399231,
#   'lon': -105.9919967651,
#   'tz': 'America/Denver'},
#  '1CO8': {'icao': '1CO8',
#   'iata': '',
#   'name': 'Everitt Airport',
#   'city': 'Parker',
#   'subd': 'Colorado',
#   'country': 'US',
#   'elevation': 6295.0,
#   'lat': 39.5292015076,
#   'lon': -104.6579971313,
#   'tz': 'America/Denver'},
#  '1DE5': {'icao': '1DE5',
#   'iata': '',
#   'name': 'Mckeown Airport',
#   'city': 'Middletown',
#   'subd': 'Delaware',
#   'country': 'US',
#   'elevation': 60.0,
#   'lat': 39.4956016541,
#   'lon': -75.7332992554,
#   'tz': 'America/New_York'},
#  '1FA1': {'icao': '1FA1',
#   'iata': '',
#   'name': 'Post Oak Ranch Airport',
#   'city': 'Crystal River',
#   'subd': 'Florida',
#   'country': 'US',
#   'elevation': 25.0,
#   'lat': 28.8558006287,
#   'lon': -82.5525970459,
#   'tz': 'America/New_York'},
#  '1FA3': {'icao': '1FA3',
#   'iata': '',
#   'name': 'Pine Island Airport',
#   'city': 'Fort Myers',
#   'subd': 'Florida',
#   'country': 'US',
#   'elevation': 12.0,
#   'lat': 26.6562004089,
#   'lon': -82.1212005615,
#   'tz': 'America/New_York'},
#  '1FD0': {'icao': '1FD0',
#   'iata': '',
#   'name': 'Lawrence Airport',
#   'city': 'Grand Ridge',
#   'subd': 'Florida',
#   'country': 'US',
#   'elevation': 130.0,
#   'lat': 30.7154998779,
#   'lon': -85.0243988037,
#   'tz': 'America/New_York'},
#  '1FD2': {'icao': '1FD2',
#   'iata': '',
#   'name': 'Bass Limited Airport',
#   'city': 'Madison',
#   'subd': 'Florida',
#   'country': 'US',
#   'elevation': 100.0,
#   'lat': 30.6194000244,
#   'lon': -83.3040008545,
#   'tz': 'America/New_York'},
#  '1FD4': {'icao': '1FD4',
#   'iata': '',
#   'name': 'Corkscrew Trace Airpark',
#   'city': 'Estero',
#   'subd': 'Florida',
#   'country': 'US',
#   'elevation': 29.0,
#   'lat': 26.445400238,
#   'lon': -81.6072998047,
#   'tz': 'America/New_York'},
#  '1FL3': {'icao': '1FL3',
#   'iata': '',
#   'name': 'Z Ranch Airport',
#   'city': 'Lake City',
#   'subd': 'Florida',
#   'country': 'US',
#   'elevation': 75.0,
#   'lat': 30.0344009399,
#   'lon': -82.7820968628,
#   'tz': 'America/New_York'},
#  '1GA0': {'icao': '1GA0',
#   'iata': '',
#   'name': 'Eagle Neck Airport',
#   'city': 'Shellman Bluff',
#   'subd': 'Georgia',
#   'country': 'US',
#   'elevation': 10.0,
#   'lat': 31.6394004822,
#   'lon': -81.3290023804,
#   'tz': 'America/New_York'},
#  '1GA2': {'icao': '1GA2',
#   'iata': '',
#   'name': 'Flying N Estates Airport',
#   'city': 'Luthersville',
#   'subd': 'Georgia',
#   'country': 'US',
#   'elevation': 870.0,
#   'lat': 33.1772994995,
#   'lon': -84.7484970093,
#   'tz': 'America/New_York'},
#  '1GA4': {'icao': '1GA4',
#   'iata': '',
#   'name': 'Southern Agricultural Aviation Airport',
#   'city': 'Statesboro',
#   'subd': 'Georgia',
#   'country': 'US',
#   'elevation': 180.0,
#   'lat': 32.3284988403,
#   'lon': -81.7554016113,
#   'tz': 'America/New_York'},
#  '1GA5': {'icao': '1GA5',
#   'iata': '',
#   'name': 'Shilo Farms Airport',
#   'city': 'Hahira',
#   'subd': 'Georgia',
#   'country': 'US',
#   'elevation': 211.0,
#   'lat': 30.9309997559,
#   'lon': -83.3834991455,
#   'tz': 'America/New_York'},
#  '1GA6': {'icao': '1GA6',
#   'iata': '',
#   'name': 'De De Airport',
#   'city': 'Barnesville',
#   'subd': 'Georgia',
#   'country': 'US',
#   'elevation': 800.0,
#   'lat': 33.0089988708,
#   'lon': -84.1107025146,
#   'tz': 'America/New_York'},
#  '1GA8': {'icao': '1GA8',
#   'iata': '',
#   'name': 'South One Ten Airport',
#   'city': 'Nashville',
#   'subd': 'Georgia',
#   'country': 'US',
#   'elevation': 225.0,
#   'lat': 31.1784992218,
#   'lon': -83.2265014648,
#   'tz': 'America/New_York'},
#  '1GA9': {'icao': '1GA9',
#   'iata': '',
#   'name': 'Aerie Airport',
#   'city': 'Monroe',
#   'subd': 'Georgia',
#   'country': 'US',
#   'elevation': 830.0,
#   'lat': 33.7615013123,
#   'lon': -83.6527023315,
#   'tz': 'America/New_York'},
#  '1GE2': {'icao': '1GE2',
#   'iata': '',
#   'name': 'C & W Air Park',
#   'city': 'Woodland',
#   'subd': 'Georgia',
#   'country': 'US',
#   'elevation': 1306.0,
#   'lat': 32.8443984985,
#   'lon': -84.5438995361,
#   'tz': 'America/New_York'},
#  '1GE3': {'icao': '1GE3',
#   'iata': '',
#   'name': 'Answered Prayer Airport',
#   'city': 'Franklin',
#   'subd': 'Georgia',
#   'country': 'US',
#   'elevation': 890.0,
#   'lat': 33.2538986206,
#   'lon': -85.1703033447,
#   'tz': 'America/New_York'},
#  '1GE4': {'icao': '1GE4',
#   'iata': '',
#   'name': 'Beckley Farms Airport',
#   'city': 'Fort Valley',
#   'subd': 'Georgia',
#   'country': 'US',
#   'elevation': 425.0,
#   'lat': 32.5010986328,
#   'lon': -83.9332962036,
#   'tz': 'America/New_York'},
#  '1GE5': {'icao': '1GE5',
#   'iata': '',
#   'name': 'Flying D Airport',
#   'city': 'Concord',
#   'subd': 'Georgia',
#   'country': 'US',
#   'elevation': 838.0,
#   'lat': 33.1012001038,
#   'lon': -84.3935012817,
#   'tz': 'America/New_York'},
#  '1GE6': {'icao': '1GE6',
#   'iata': '',
#   'name': 'Forestry-Strip Airport',
#   'city': 'Patterson',
#   'subd': 'Georgia',
#   'country': 'US',
#   'elevation': 105.0,
#   'lat': 31.3724002838,
#   'lon': -82.1234970093,
#   'tz': 'America/New_York'},
#  '1GE7': {'icao': '1GE7',
#   'iata': '',
#   'name': 'Hay Field',
#   'city': 'Madison',
#   'subd': 'Georgia',
#   'country': 'US',
#   'elevation': 650.0,
#   'lat': 33.51720047,
#   'lon': -83.4396972656,
#   'tz': 'America/New_York'},
#  '1GE9': {'icao': '1GE9',
#   'iata': '',
#   'name': 'Waverly Landing Airport',
#   'city': 'Waverly Hall',
#   'subd': 'Georgia',
#   'country': 'US',
#   'elevation': 675.0,
#   'lat': 32.7144012451,
#   'lon': -84.7181015015,
#   'tz': 'America/New_York'},
#  '1IA0': {'icao': '1IA0',
#   'iata': '',
#   'name': 'Brown Truck Sales Airport',
#   'city': 'Corning',
#   'subd': 'Iowa',
#   'country': 'US',
#   'elevation': 1300.0,
#   'lat': 40.8972015381,
#   'lon': -94.7910995483,
#   'tz': 'America/Chicago'},
#  '1IA4': {'icao': '1IA4',
#   'iata': '',
#   'name': 'Wallace Field',
#   'city': 'Creston',
#   'subd': 'Iowa',
#   'country': 'US',
#   'elevation': 1290.0,
#   'lat': 41.0555000305,
#   'lon': -94.3946990967,
#   'tz': 'America/Chicago'},
#  '1IA6': {'icao': '1IA6',
#   'iata': '',
#   'name': 'Aero-Lane Airport',
#   'city': 'Randolph',
#   'subd': 'Iowa',
#   'country': 'US',
#   'elevation': 1134.0,
#   'lat': 40.8849983215,
#   'lon': -95.4852981567,
#   'tz': 'America/Chicago'},
#  ...}

# %% [markdown]
# ## Depart

# %%
####################################################
####################################################
####################################################
#
# End of Script
#

print("Ploting Meteogram Script complete.")

#
####################################################
####################################################
####################################################
