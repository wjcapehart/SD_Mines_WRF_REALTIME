# %% [markdown]
# # Plot Time Series w/ Observations

# %% [markdown]
# ## Libraries

# %%
####################################################
####################################################
####################################################
#
# Libraries
#

import numpy             as np
import datetime          as datetime
import os                as os
import platform          as platform
import xarray            as xr
import pandas            as pd
import glob              as glob
import siphon.catalog    as siphcat  
import siphon.ncss       as siphncss
import seaborn           as sns
import matplotlib.pyplot as plt
import pint_xarray       as px
import matplotlib.dates  as mdates
import timezonefinder    as tzf
import pytz              as pytz
import haversine         as hs
import socket            as socket
import metpy.calc        as mpcalc
import metpy.units       as mpunits

import metpy.io          as mpio
from metpy.cbook import get_test_data
from siphon.catalog import TDSCatalog

import matplotlib.font_manager as fm
import matplotlib as mpl

from requests import HTTPError

import urllib.request
import shutil


from metpy.units import units

import requests


os.chdir("/Users/wjc/GitHub/SD_Mines_WRF_REALTIME/test_area/")
os.getcwd()
#
####################################################
####################################################
####################################################
# Out:
# '/Users/wjc/GitHub/SD_Mines_WRF_REALTIME/test_area'

# %% [markdown]
# ## File Organization

# %%
####################################################
####################################################
####################################################
#
# File Organization
#

beta_on     = 0
max_domains = 3

if (socket.gethostname() == "kyrill"):
    WRF_OVERALL_DIR = "/projects/SD_Mines_WRF_REALTIME/"
else:
    if (platform.system() == "Darwin"):
         WRF_OVERALL_DIR = "/Users/wjc/GitHub/SD_Mines_WRF_REALTIME/"
    else:
         WRF_OVERALL_DIR = "/home/wjc/GitHub/SD_Mines_WRF_REALTIME/"



print( "Current Working Directory is now " + os.getcwd() )
    
WPS_WORK    = WRF_OVERALL_DIR + "./WPS_PrepArea/"
WPS_EXE     = WRF_OVERALL_DIR + "./WRF4/WPS/"
WRF_EXE     = WRF_OVERALL_DIR + "./WRF4/WRF/test/em_real/"
WRF_ARCHIVE = WRF_OVERALL_DIR + "./ARCHIVE/"
WRF_IMAGES  = WRF_OVERALL_DIR + "./WEB_IMAGES/"



station_list_file = WRF_OVERALL_DIR + "namelist_files_and_local_scripts/time_series_station_files_"+str(max_domains)+"_dom_all.xlsx"


#
####################################################
####################################################
####################################################
# Out:
# Current Working Directory is now /Users/wjc/GitHub/SD_Mines_WRF_REALTIME/test_area

# %% [markdown]
# ## Time Control

# %%
####################################################
####################################################
####################################################
#
# Model Start Date
#

with open(WRF_ARCHIVE  + "./current_complete_run/current_run.txt") as f:
    model_start_date_YYYY_MM_DD_HH = f.readlines()

model_start_date_YYYY_MM_DD_HH     = model_start_date_YYYY_MM_DD_HH[0][0:13]

model_start_date_YYYY_MM_DD_HH0000 = model_start_date_YYYY_MM_DD_HH + ":00:00"
print(model_start_date_YYYY_MM_DD_HH0000)
    
model_start_datetime = datetime.datetime.strptime(model_start_date_YYYY_MM_DD_HH0000, '%Y-%m-%d_%H:%M:%S')
print("Model Simulation Date ", model_start_datetime)
    
model_end_datetime   = model_start_datetime + datetime.timedelta(hours=36)
current_datetime     = datetime.datetime.utcnow()
siphon_end_datetime  = min(current_datetime,model_end_datetime)

print("         Model Start Datetime is ", model_start_datetime)
print("           Model End Datetime is ",   model_end_datetime)
print("             Current Datetime is ",     current_datetime)
print("          Siphon End Datetime is ",  siphon_end_datetime)

siphon_time_series       = pd.date_range(model_start_datetime, siphon_end_datetime,freq='H')
siphon_pulls_YYYYMMDD_HH = siphon_time_series.strftime("%Y%m%d_%H00")

print(siphon_pulls_YYYYMMDD_HH)

#
####################################################
####################################################
####################################################
# Out:
# 2021-10-24_00:00:00
# Model Simulation Date  2021-10-24 00:00:00
#          Model Start Datetime is  2021-10-24 00:00:00
#            Model End Datetime is  2021-10-25 12:00:00
#              Current Datetime is  2021-10-25 16:47:38.882806
#           Siphon End Datetime is  2021-10-25 12:00:00
# Index(['20211024_0000', '20211024_0100', '20211024_0200', '20211024_0300',
#        '20211024_0400', '20211024_0500', '20211024_0600', '20211024_0700',
#        '20211024_0800', '20211024_0900', '20211024_1000', '20211024_1100',
#        '20211024_1200', '20211024_1300', '20211024_1400', '20211024_1500',
#        '20211024_1600', '20211024_1700', '20211024_1800', '20211024_1900',
#        '20211024_2000', '20211024_2100', '20211024_2200', '20211024_2300',
#        '20211025_0000', '20211025_0100', '20211025_0200', '20211025_0300',
#        '20211025_0400', '20211025_0500', '20211025_0600', '20211025_0700',
#        '20211025_0800', '20211025_0900', '20211025_1000', '20211025_1100',
#        '20211025_1200'],
#       dtype='object')

# %% [markdown]
# ## Read tslist excel file

# %%
####################################################
####################################################
####################################################
#
# Read TSLIST Excel File
#

print("read file from "+station_list_file)

available_time_series_list = pd.read_excel(station_list_file,
                                           index_col=0)

print(available_time_series_list)

#
####################################################
####################################################
####################################################
# Out:
# read file from /Users/wjc/GitHub/SD_Mines_WRF_REALTIME/namelist_files_and_local_scripts/time_series_station_files_3_dom_all.xlsx
#           Station ID  Domain            Station Name  Latitude  Longitude  \
# Row Label
# 26              KUNR       3      Rapid City NWS, SD   44.0727   -103.211
# 21              KRCA       3       Ellsworth AFB, SD   44.1330   -103.100
# 20              KRAP       3     Rapid City Arpt, SD   44.0430   -103.054
# 25              KUDX       3  Rapid City, NEXRAD, SD   44.1330   -102.833
# 7               KCUT       3         Custer Arpt, SD   43.7330   -103.611
# 23              KSPF       3     Clyde Ice Field, SD   44.4830   -103.783
# 10              KEFC       3  Belle Fourche Muni, SD   44.7340   -103.862
# 28              KW43       3         Hulett Arpt, WY   44.6629   -104.568
# 18              KPHP       2         Philip Arpt, SD   44.0510   -101.601
# 15              KIEN       2     Pine Ridge Arpt, SD   43.0210   -102.518
# 6               KCDR       2     Chadron Airport, NE   42.8370   -103.098
# 2               K4MC       2           Moorcroft, WY   44.2670   -104.950
# 8               KD07       2       Faith Airport, SD   45.0320   -102.019
# 12              KGRN       2         Gordon Muni, NE   42.8060   -102.175
# 0               K2WX       2             Buffalo, SD   45.6040   -103.546
# 11              KGCC       2       Gillette Arpt, WY   44.3390   -105.542
# 14              KHEI       2      Hettinger Arpt, ND   46.0170   -102.650
# 29              KY22       2              Lemmon, SD   45.9330   -102.167
# 16              KLEM       2         Lemmon Arpt, SD   45.9190   -102.106
# 9               KDGW       2    Converse Co Arpt, WY   42.7960   -105.380
# 3               KAIA       1       Alliance Arpt, NE   42.0500   -102.800
# 1               K4DG       2             Douglas, WY   42.7500   -105.383
# 22              KSIB       1         Sibley Peak, WY   42.4330   -105.033
# 19              KPIR       2         Pierre Arpt, SD   44.3810   -100.286
# 5               KBPP       2         Bowman Arpt, ND   46.1870   -103.428
# 24              KTOR       1     Torrington Arpt, WY   42.0610   -104.158
# 17              KMIS       2             Mission, SD   43.0330   -100.617
# 4               KBFF       1    Scottsbluff Arpt, NE   41.8710   -103.593
# 27              KVTN       2   Miller Field Arpt, NE   42.8780   -100.550
# 30              MUNS       1       Munich School, ND   48.6667    -98.835
#
#            Distane from SDMines
# Row Label
# 26                     0.440247
# 21                    10.688775
# 20                    12.624087
# 25                    30.484424
# 7                     49.927564
# 23                    64.629983
# 10                    89.994938
# 28                   126.519155
# 18                   128.259607
# 15                   129.569530
# 6                    137.845928
# 2                    140.743165
# 8                    142.080009
# 12                   163.745344
# 0                    172.206435
# 11                   188.512672
# 14                   220.398591
# 29                   222.238035
# 16                   222.613287
# 9                    225.856417
# 3                    227.482904
# 1                    229.345787
# 22                   234.931317
# 19                   235.131061
# 5                    235.577856
# 24                   236.837323
# 17                   238.584887
# 4                    247.000181
# 27                   252.207141
# 30                   610.696746

# %%
####################################################
####################################################
####################################################
#
# Pull METARS from UNIDATA NOAAPORT Experimental Site
#

# https://thredds-test.unidata.ucar.edu/thredds/fileServer/noaaport/text/metar/metar_20210924_0000.txt

cat = TDSCatalog('https://thredds-test.unidata.ucar.edu/thredds/catalog/noaaport/text/metar/catalog.xml')



first = True
for datehour in siphon_pulls_YYYYMMDD_HH:
    

    
    metar_url  = "https://thredds-test.unidata.ucar.edu/thredds/fileServer/noaaport/text/metar/metar_"+datehour+".txt"
    metar_file = "deleteme.txt"
    
    print(metar_url)

    with urllib.request.urlopen(metar_url) as response, open(metar_file, 'wb') as out_file:
        shutil.copyfileobj(response, out_file)
        
    try:
        indata = mpio.metar.parse_metar_file(metar_file)
        if first:
            first = False
            metar_dataframe = indata
        else:
            metar_dataframe = metar_dataframe.append(indata)
            metar_dataframe = metar_dataframe.drop_duplicates()
    except ValueError:
        print("BALLS! Parse Error")
        error_404 = True
        pass


        
        


display(metar_dataframe)





#
####################################################
####################################################
####################################################
# Out:
# https://thredds-test.unidata.ucar.edu/thredds/fileServer/noaaport/text/metar/metar_20211024_0000.txt
# https://thredds-test.unidata.ucar.edu/thredds/fileServer/noaaport/text/metar/metar_20211024_0100.txt
# https://thredds-test.unidata.ucar.edu/thredds/fileServer/noaaport/text/metar/metar_20211024_0200.txt
# https://thredds-test.unidata.ucar.edu/thredds/fileServer/noaaport/text/metar/metar_20211024_0300.txt
# https://thredds-test.unidata.ucar.edu/thredds/fileServer/noaaport/text/metar/metar_20211024_0400.txt
# https://thredds-test.unidata.ucar.edu/thredds/fileServer/noaaport/text/metar/metar_20211024_0500.txt
# https://thredds-test.unidata.ucar.edu/thredds/fileServer/noaaport/text/metar/metar_20211024_0600.txt
# https://thredds-test.unidata.ucar.edu/thredds/fileServer/noaaport/text/metar/metar_20211024_0700.txt
# BALLS! Parse Error
# https://thredds-test.unidata.ucar.edu/thredds/fileServer/noaaport/text/metar/metar_20211024_0800.txt
# BALLS! Parse Error
# https://thredds-test.unidata.ucar.edu/thredds/fileServer/noaaport/text/metar/metar_20211024_0900.txt
# https://thredds-test.unidata.ucar.edu/thredds/fileServer/noaaport/text/metar/metar_20211024_1000.txt
# https://thredds-test.unidata.ucar.edu/thredds/fileServer/noaaport/text/metar/metar_20211024_1100.txt
# https://thredds-test.unidata.ucar.edu/thredds/fileServer/noaaport/text/metar/metar_20211024_1200.txt
# https://thredds-test.unidata.ucar.edu/thredds/fileServer/noaaport/text/metar/metar_20211024_1300.txt
# https://thredds-test.unidata.ucar.edu/thredds/fileServer/noaaport/text/metar/metar_20211024_1400.txt
# https://thredds-test.unidata.ucar.edu/thredds/fileServer/noaaport/text/metar/metar_20211024_1500.txt
# https://thredds-test.unidata.ucar.edu/thredds/fileServer/noaaport/text/metar/metar_20211024_1600.txt
# https://thredds-test.unidata.ucar.edu/thredds/fileServer/noaaport/text/metar/metar_20211024_1700.txt
# https://thredds-test.unidata.ucar.edu/thredds/fileServer/noaaport/text/metar/metar_20211024_1800.txt
# https://thredds-test.unidata.ucar.edu/thredds/fileServer/noaaport/text/metar/metar_20211024_1900.txt
# https://thredds-test.unidata.ucar.edu/thredds/fileServer/noaaport/text/metar/metar_20211024_2000.txt
# https://thredds-test.unidata.ucar.edu/thredds/fileServer/noaaport/text/metar/metar_20211024_2100.txt
# https://thredds-test.unidata.ucar.edu/thredds/fileServer/noaaport/text/metar/metar_20211024_2200.txt
# https://thredds-test.unidata.ucar.edu/thredds/fileServer/noaaport/text/metar/metar_20211024_2300.txt
# https://thredds-test.unidata.ucar.edu/thredds/fileServer/noaaport/text/metar/metar_20211025_0000.txt
# BALLS! Parse Error
# https://thredds-test.unidata.ucar.edu/thredds/fileServer/noaaport/text/metar/metar_20211025_0100.txt
# https://thredds-test.unidata.ucar.edu/thredds/fileServer/noaaport/text/metar/metar_20211025_0200.txt
# https://thredds-test.unidata.ucar.edu/thredds/fileServer/noaaport/text/metar/metar_20211025_0300.txt
# https://thredds-test.unidata.ucar.edu/thredds/fileServer/noaaport/text/metar/metar_20211025_0400.txt
# https://thredds-test.unidata.ucar.edu/thredds/fileServer/noaaport/text/metar/metar_20211025_0500.txt
# https://thredds-test.unidata.ucar.edu/thredds/fileServer/noaaport/text/metar/metar_20211025_0600.txt
# https://thredds-test.unidata.ucar.edu/thredds/fileServer/noaaport/text/metar/metar_20211025_0700.txt
# https://thredds-test.unidata.ucar.edu/thredds/fileServer/noaaport/text/metar/metar_20211025_0800.txt
# https://thredds-test.unidata.ucar.edu/thredds/fileServer/noaaport/text/metar/metar_20211025_0900.txt
# https://thredds-test.unidata.ucar.edu/thredds/fileServer/noaaport/text/metar/metar_20211025_1000.txt
# https://thredds-test.unidata.ucar.edu/thredds/fileServer/noaaport/text/metar/metar_20211025_1100.txt
# https://thredds-test.unidata.ucar.edu/thredds/fileServer/noaaport/text/metar/metar_20211025_1200.txt
#            station_id   latitude  longitude  elevation           date_time  \
# station_id
# KPOC             KPOC  34.100000    -117.77      308.0 2021-10-23 23:47:00
# KMJD             KMJD  30.483333     -89.65       17.0 2021-10-23 23:55:00
# KC62             KC62  41.470000     -85.27      306.0 2021-10-23 23:55:00
# KLBE             KLBE  40.270000     -79.40      361.0 2021-10-23 23:47:00
# KFMH             KFMH  41.630000     -70.52       40.0 2021-10-23 23:45:00
# ...               ...        ...        ...        ...                 ...
# UKON             UKON  47.050000      31.92       56.0 2021-10-25 13:30:00
# UKOO             UKOO  46.420000      30.68       35.0 2021-10-25 13:30:00
# KNKT             KNKT  34.900000     -76.88        9.0 2021-10-25 11:54:00
# HTTB             HTTB  -5.070000      32.82     1190.0 2021-10-25 12:00:00
# HKMO             HKMO  -4.010000      39.61       55.0 2021-10-25 12:00:00
#
#             wind_direction  wind_speed  visibility current_wx1 current_wx2  \
# station_id
# KPOC                 270.0    7.000000   16093.440         NaN         NaN
# KMJD                   0.0    0.000000         NaN         NaN         NaN
# KC62                   0.0    0.000000   16093.440         NaN         NaN
# KLBE                 180.0    7.000000   16093.440         NaN         NaN
# KFMH                   0.0    0.000000   16093.440         NaN         NaN
# ...                    ...         ...         ...         ...         ...
# UKON                 360.0    3.887689   10000.000         NaN         NaN
# UKOO                  80.0    3.887689   10000.000         NaN         NaN
# KNKT                 190.0   11.000000    4828.032          RA          BR
# HTTB                 180.0    5.000000    9999.000         NaN         NaN
# HKMO                 140.0   10.000000    9999.000         NaN         NaN
#
#             ... air_temperature dew_point_temperature  altimeter  \
# station_id  ...
# KPOC        ...            17.0                  13.0      29.88
# KMJD        ...            23.0                  20.0      29.98
# KC62        ...             8.0                   2.0      30.02
# KLBE        ...             8.0                   8.0      30.05
# KFMH        ...            10.0                   9.0      29.93
# ...         ...             ...                   ...        ...
# UKON        ...             8.0                  -2.0      30.50
# UKOO        ...             9.0                  -0.0      30.50
# KNKT        ...            21.0                  19.0      30.02
# HTTB        ...            32.0                  13.0      30.00
# HKMO        ...            30.0                  23.0      29.91
#
#            current_wx1_symbol  current_wx2_symbol current_wx3_symbol  \
# station_id
# KPOC                        0                   0                  0
# KMJD                        0                   0                  0
# KC62                        0                   0                  0
# KLBE                        0                   0                  0
# KFMH                        0                   0                  0
# ...                       ...                 ...                ...
# UKON                        0                   0                  0
# UKOO                        0                   0                  0
# KNKT                       63                  10                  0
# HTTB                        0                   0                  0
# HKMO                        0                   0                  0
#
#                                                       remarks  \
# station_id
# KPOC
# KMJD                                                      AO2
# KC62                                            AO2 T00910019
# KLBE
# KFMH
# ...                                                       ...
# UKON                                         R04/090075 NOSIG
# UKOO                                         R16/090095 NOSIG
# KNKT        RAB49 TSB30E45 SLP164 P0007 60007 70007 T02110...
# HTTB
# HKMO                                                    NOSIG
#
#            air_pressure_at_sea_level  eastward_wind  northward_wind
# station_id
# KPOC                         1011.75   7.000000e+00    1.285879e-15
# KMJD                         1015.48  -0.000000e+00   -0.000000e+00
# KC62                         1017.70  -0.000000e+00   -0.000000e+00
# KLBE                         1018.84  -8.572528e-16    7.000000e+00
# KFMH                         1013.93  -0.000000e+00   -0.000000e+00
# ...                              ...            ...             ...
# UKON                         1033.49   9.522092e-16   -3.887689e+00
# UKOO                         1033.40  -3.828626e+00   -6.750901e-01
# KNKT                         1016.87   1.910130e+00    1.083289e+01
# HTTB                         1006.45  -6.123234e-16    5.000000e+00
# HKMO                         1012.97  -6.427876e+00    7.660444e+00
#
# [285960 rows x 30 columns]

# %%
# Out:
#            station_id  latitude  longitude  elevation           date_time  \
# station_id
# KRAP             KRAP     44.05    -103.05      965.0 2021-10
# KRAP                         1007.46  -0.000000e+00   -0.000000e+00
# KRAP                         1008.23   1.224647e-15   -5.000000e+00
# KRAP                         1008.23   1.959435e-15   -8.000000e+00
# KRAP                         1008.66  -1.389185e+00   -7.878462e+00
# KRAP                         1008.66   4.500000e+00   -7.794229e+00
# KRAP                         1009.00   5.130302e+00   -1.409539e+01
# KRAP                         1009.70   2.257426e+00   -1.280250e+01
# KRAP                         1009.96   5.472322e+00   -1.503508e+01
# KRAP                         1011.17   1.562834e+00   -8.863270e+00
# KRAP                         1011.78   5.362311e+00   -4.499513e+00
# KRAP                         1012.39   3.213938e+00   -3.830222e+00
# KRAP                         1012.32  -3.000000e+00   -5.196152e+00
# KRAP                         1011.90  -2.394141e+00   -6.577848e+00
# KRAP                         1011.34            NaN             NaN
# KRAP                         1010.59            NaN             NaN
# KRAP                         1009.84   1.714506e-15   -7.000000e+00
# KRAP                         1009.78            NaN             NaN
# KRAP                         1010.13  -4.000000e+00   -6.928203e+00
# KRAP                         1011.28  -5.196152e+00   -3.000000e+00
# KRAP                         1014.47  -8.000000e+00   -4.898587e-16
# KRAP                         1015.25  -9.396926e+00    3.420201e+00
# KRAP                         1016.90  -2.571150e+00    3.064178e+00
# KRAP                         1018.29  -5.196152e+00    3.000000e+00
# KRAP                         1018.73  -4.330127e+00    2.500000e+00
# KRAP                         1018.73  -3.213938e+00    3.830222e+00
# KRAP                         1018.73  -5.638156e+00    2.052121e+00
# KRAP                         1018.38  -6.577848e+00    2.394141e+00
# KRAP                         1018.38  -5.638156e+00    2.052121e+00
# KRAP                         1018.38  -4.330127e+00    2.500000e+00
# KRAP                         1018.38  -6.577848e+00    2.394141e+00
# KRAP                         1017.59  -8.660254e+00    5.000000e+00
# KRAP                         1017.59  -9.958578e+00    8.356239e+00
# KRAP                         1017.59  -9.192533e+00    7.713451e+00
# KRAP                         1017.25  -7.660444e+00    6.427876e+00
# KRAP                         1017.25  -6.427876e+00    7.660444e+00
# KRAP                         1017.25  -6.427876e+00    7.660444e+00
# KRAP                         1017.25  -6.000000e+00    1.039230e+01
# KRAP                         1017.25  -7.070664e+00    8.426489e+00
# KRAP                         1016.55  -6.000000e+00    1.039230e+01
# KRAP                         1016.20  -6.500000e+00    1.125833e+01
# KRAP                         1015.86  -7.500000e+00    1.299038e+01
# KRAP                         1016.30  -6.500000e+00    1.125833e+01
# KRAP                         1015.60  -4.446262e+00    1.221600e+01
#
# [46 rows x 30 columns]

# %% [markdown]
# ## Rotate through Available Files

# %%
####################################################
####################################################
####################################################
#
# Rotate through Available Files
#

file_time = model_start_datetime.strftime('%Y-%m-%d_%H')

TS_DIR    = WRF_ARCHIVE  + "./current_complete_run/STATION_TIME_SERIES/"

#
# Creating Graphics Directory
#

graphics_directory = WRF_IMAGES + "./current_complete_run/STATION_TIME_SERIES/"

print("Creating " + graphics_directory)

os.system("mkdir -pv " + graphics_directory )

#
# Start File Rotation
#

for station in available_time_series_list.iterrows():
    
    
    print(" ")
    
    print("============")



    ###################################################################
    #
    # Pull Station Data 
    #

    station_id     = station[1][0]
    grid_domain    = station[1][1]
    station_name   = station[1][2]
    station_lat    = station[1][3]
    station_lon    = station[1][4]

    #    
    ###################################################################
    

    
    station_data = metar_dataframe[metar_dataframe["station_id"]==station_id]

    print(station_id,len(station_data))
# Out:
# Creating /Users/wjc/GitHub/SD_Mines_WRF_REALTIME/./WEB_IMAGES/./current_complete_run/STATION_TIME_SERIES/
#
# (26, Station ID                            KUNR
# Domain                                   3
# Station Name            Rapid City NWS, SD
# Latitude                           44.0727
# Longitude                         -103.211
# Distane from SDMines              0.440247
# Name: 26, dtype: object)
#
# (21, Station ID                           KRCA
# Domain                                  3
# Station Name            Ellsworth AFB, SD
# Latitude                           44.133
# Longitude                          -103.1
# Distane from SDMines            10.688775
# Name: 21, dtype: object)
#
# (20, Station ID                             KRAP
# Domain                                    3
# Station Name            Rapid City Arpt, SD
# Latitude                             44.043
# Longitude                          -103.054
# Distane from SDMines              12.624087
# Name: 20, dtype: object)
#
# (25, Station ID                                KUDX
# Domain                                       3
# Station Name            Rapid City, NEXRAD, SD
# Latitude                                44.133
# Longitude                             -102.833
# Distane from SDMines                 30.484424
# Name: 25, dtype: object)
#
# (7, Station ID                         KCUT
# Domain                                3
# Station Name            Custer Arpt, SD
# Latitude                         43.733
# Longitude                      -103.611
# Distane from SDMines          49.927564
# Name: 7, dtype: object)
#
# (23, Station ID                             KSPF
# Domain                                    3
# Station Name            Clyde Ice Field, SD
# Latitude                             44.483
# Longitude                          -103.783
# Distane from SDMines              64.629983
# Name: 23, dtype: object)
#
# (10, Station ID                                KEFC
# Domain                                       3
# Station Name            Belle Fourche Muni, SD
# Latitude                                44.734
# Longitude                             -103.862
# Distane from SDMines                 89.994938
# Name: 10, dtype: object)
#
# (28, Station ID                         KW43
# Domain                                3
# Station Name            Hulett Arpt, WY
# Latitude                        44.6629
# Longitude                      -104.568
# Distane from SDMines         126.519155
# Name: 28, dtype: object)
#
# (18, Station ID                         KPHP
# Domain                                2
# Station Name            Philip Arpt, SD
# Latitude                         44.051
# Longitude                      -101.601
# Distane from SDMines         128.259607
# Name: 18, dtype: object)
#
# (15, Station ID                             KIEN
# Domain                                    2
# Station Name            Pine Ridge Arpt, SD
# Latitude                             43.021
# Longitude                          -102.518
# Distane from SDMines              129.56953
# Name: 15, dtype: object)
#
# (6, Station ID                             KCDR
# Domain                                    2
# Station Name            Chadron Airport, NE
# Latitude                             42.837
# Longitude                          -103.098
# Distane from SDMines             137.845928
# Name: 6, dtype: object)
#
# (2, Station ID                       K4MC
# Domain                              2
# Station Name            Moorcroft, WY
# Latitude                       44.267
# Longitude                     -104.95
# Distane from SDMines       140.743165
# Name: 2, dtype: object)
#
# (8, Station ID                           KD07
# Domain                                  2
# Station Name            Faith Airport, SD
# Latitude                           45.032
# Longitude                        -102.019
# Distane from SDMines           142.080009
# Name: 8, dtype: object)
#
# (12, Station ID                         KGRN
# Domain                                2
# Station Name            Gordon Muni, NE
# Latitude                         42.806
# Longitude                      -102.175
# Distane from SDMines         163.745344
# Name: 12, dtype: object)
#
# (0, Station ID                     K2WX
# Domain                            2
# Station Name            Buffalo, SD
# Latitude                     45.604
# Longitude                  -103.546
# Distane from SDMines     172.206435
# Name: 0, dtype: object)
#
# (11, Station ID                           KGCC
# Domain                                  2
# Station Name            Gillette Arpt, WY
# Latitude                           44.339
# Longitude                        -105.542
# Distane from SDMines           188.512672
# Name: 11, dtype: object)
#
# (14, Station ID                            KHEI
# Domain                                   2
# Station Name            Hettinger Arpt, ND
# Latitude                            46.017
# Longitude                          -102.65
# Distane from SDMines            220.398591
# Name: 14, dtype: object)
#
# (29, Station ID                    KY22
# Domain                           2
# Station Name            Lemmon, SD
# Latitude                    45.933
# Longitude                 -102.167
# Distane from SDMines    222.238035
# Name: 29, dtype: object)
#
# (16, Station ID                         KLEM
# Domain                                2
# Station Name            Lemmon Arpt, SD
# Latitude                         45.919
# Longitude                      -102.106
# Distane from SDMines         222.613287
# Name: 16, dtype: object)
#
# (9, Station ID                              KDGW
# Domain                                     2
# Station Name            Converse Co Arpt, WY
# Latitude                              42.796
# Longitude                            -105.38
# Distane from SDMines              225.856417
# Name: 9, dtype: object)
#
# (3, Station ID                           KAIA
# Domain                                  1
# Station Name            Alliance Arpt, NE
# Latitude                            42.05
# Longitude                          -102.8
# Distane from SDMines           227.482904
# Name: 3, dtype: object)
#
# (1, Station ID                     K4DG
# Domain                            2
# Station Name            Douglas, WY
# Latitude                      42.75
# Longitude                  -105.383
# Distane from SDMines     229.345787
# Name: 1, dtype: object)
#
# (22, Station ID                         KSIB
# Domain                                1
# Station Name            Sibley Peak, WY
# Latitude                         42.433
# Longitude                      -105.033
# Distane from SDMines         234.931317
# Name: 22, dtype: object)
#
# (19, Station ID                         KPIR
# Domain                                2
# Station Name            Pierre Arpt, SD
# Latitude                         44.381
# Longitude                      -100.286
# Distane from SDMines         235.131061
# Name: 19, dtype: object)
#
# (5, Station ID                         KBPP
# Domain                                2
# Station Name            Bowman Arpt, ND
# Latitude                         46.187
# Longitude                      -103.428
# Distane from SDMines         235.577856
# Name: 5, dtype: object)
#
# (24, Station ID                             KTOR
# Domain                                    1
# Station Name            Torrington Arpt, WY
# Latitude                             42.061
# Longitude                          -104.158
# Distane from SDMines             236.837323
# Name: 24, dtype: object)
#
# (17, Station ID                     KMIS
# Domain                            2
# Station Name            Mission, SD
# Latitude                     43.033
# Longitude                  -100.617
# Distane from SDMines     238.584887
# Name: 17, dtype: object)
#
# (4, Station ID                              KBFF
# Domain                                     1
# Station Name            Scottsbluff Arpt, NE
# Latitude                              41.871
# Longitude                           -103.593
# Distane from SDMines              247.000181
# Name: 4, dtype: object)
#
# (27, Station ID                               KVTN
# Domain                                      2
# Station Name            Miller Field Arpt, NE
# Latitude                               42.878
# Longitude                             -100.55
# Distane from SDMines               252.207141
# Name: 27, dtype: object)
#
# (30, Station ID                           MUNS
# Domain                                  1
# Station Name            Munich School, ND
# Latitude                          48.6667
# Longitude                         -98.835
# Distane from SDMines           610.696746
# Name: 30, dtype: object)

# %% [markdown]
# ## Depart

# %%
####################################################
####################################################
####################################################
#
# End of Script
#

print("Ploting Meteogram Script complete.")

#
####################################################
####################################################
####################################################
# Out:
# Ploting Meteogram Script complete.
